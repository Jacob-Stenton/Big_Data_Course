# %%
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials

from spotify_credentials import Client_ID, Client_Secret_ID

# %%
auth_manager = SpotifyClientCredentials(Client_ID, Client_Secret_ID)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
#PLaylist = https://open.spotify.com/playlist/37i9dQZEVXcKGLbpyB1DvZ?si=c6503ab354e94334
#Song = https://open.spotify.com/track/1cg4xD453Wuol9fNsRDbsV?si=ae0da0c5fd884757
PLAYLIST_ID = "37i9dQZEVXcKGLbpyB1DvZ"
TRACK_ID = "1cg4xD453Wuol9fNsRDbsV"
track_info = sp.track(TRACK_ID)

# %%
track_analysis = sp.audio_analysis(TRACK_ID)
track_analysis
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1713925580,
#   'analysis_time': 6.01817,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 4882990,
#   'duration': 221.45079,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 0.25497,
#   'start_of_fade_out': 216.60735,
#   'loudness': -5.677,
#   'tempo': 98.021,
#   'tempo_confidence': 0.241,
#   'time_signature': 4,
#   'time_signature_confidence': 1.0,
#   'key': 10,
#   'key_confidence': 0.759,
#   'mode': 1,
#   'mode_confidence': 0.641,
# ...
