# %%
import spotipy

from spotipy.oauth2 import SpotifyClientCredentials

# Make sure you have created a spotify_credentials.py file in the same directory as this notebook.
# the contents should be:
# CLIENT_ID = 'YOUR_CLIENT_ID'
# CLIENT_SECRET_ID = 'YOUR CLIENT_SECRET_ID'
from spotify_credentials import CLIENT_ID, CLIENT_SECRET_ID

# %%
# playlist url
# https://open.spotify.com/playlist/37i9dQZF1DX7iB3RCnBnN4?si=9d199f5212064db7

# %%
# authenticate and initialise the Spotipy object
# to get the credentials
auth_manager = SpotifyClientCredentials(CLIENT_ID, CLIENT_SECRET_ID)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# song URL = https://open.spotify.com/track/6IPwKM3fUUzlElbvKw2sKl?si=8a9888fa74cf4f4a

# How to get a track id? From a sharing link:
# https://open.spotify.com/track/6IPwKM3fUUzlElbvKw2sKl?si=8a9888fa74cf4f4a

# https://open.spotify.com/track/{TRACK_ID}?si=8a9888fa74cf4f4a

# In a similar way, you can access data about artists, albums, playlists, etc.

TRACK_ID = '6IPwKM3fUUzlElbvKw2sKl'

track_info = sp.track(TRACK_ID)

# %%
# display all the available info
from pprint import pprint
pprint(list(track_info.keys()))
# Out:
# ['album',
#  'artists',
#  'available_markets',
#  'disc_number',
#  'duration_ms',
#  'explicit',
#  'external_ids',
#  'external_urls',
#  'href',
#  'id',
#  'is_local',
#  'name',
#  'popularity',
#  'preview_url',
#  'track_number',
#  'type',
#  'uri']

# %%
#  we'll get data about release year, id, name, and artist names
track_info['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3uwAm6vQy7kWPS2bciKWx9'},
#   'href': 'https://api.spotify.com/v1/artists/3uwAm6vQy7kWPS2bciKWx9',
#   'id': '3uwAm6vQy7kWPS2bciKWx9',
#   'name': 'girl in red',
#   'type': 'artist',
#   'uri': 'spotify:artist:3uwAm6vQy7kWPS2bciKWx9'}]

# %%
# get a list of artist names by iterating over the artist info in the json
artist_names = [
    artist['name']
    for artist
    in track_info['artists']
]

# %%
# get the release year from the reease date (formatted in the YYYY-MM-DD convention)
release_year = track_info['album']['release_date'].split('-')[0]
release_year
# Out:
# '2018'

# %%
# get the spotify URL to the track
spotify_url = track_info['external_urls']['spotify']
spotify_url
# Out:
# 'https://open.spotify.com/track/6IPwKM3fUUzlElbvKw2sKl'

# %%
# combine all the info into one dict that we will want to save to the db
def get_track_info(track_info):
    # track_info = sp.track(track_id)

    artist_names = [artist['name'] for artist in track_info['artists']]
    release_year = track_info['album']['release_date'].split('-')[0]
    spotify_url = track_info['external_urls']['spotify']

    track_data = {
        'artists': artist_names,
        'id': track_info['id'],
        'name': track_info['name'],
        'release_year': release_year,
        'spotify_url': spotify_url,
    }
    return track_data

# %%
# let's see how it works!
get_track_info(TRACK_ID)
# Out:
# {'artists': ['girl in red'],
#  'id': '6IPwKM3fUUzlElbvKw2sKl',
#  'name': 'we fell in love in october',
#  'release_year': '2018',
#  'spotify_url': 'https://open.spotify.com/track/6IPwKM3fUUzlElbvKw2sKl'}

# %%
# playlist url
# https://open.spotify.com/playlist/37i9dQZF1DX7iB3RCnBnN4?si=9d199f5212064db7
PLAYLIST_ID = '37i9dQZF1DX7iB3RCnBnN4'
playlist_info = sp.playlist(PLAYLIST_ID)

# %%
pprint.pprint(list(playlist_info.keys()))
# Out:
# ['collaborative',
#  'description',
#  'external_urls',
#  'followers',
#  'href',
#  'id',
#  'images',
#  'name',
#  'owner',
#  'primary_color',
#  'public',
#  'snapshot_id',
#  'tracks',
#  'type',
#  'uri']

# %%
pprint.pprint(playlist_info['tracks'])
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7iB3RCnBnN4/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-04-10T18:35:44Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                              'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                              'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                              'name': 'Shawn Mendes',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#                                 'available_markets': ['AR',
#                                                       'AU',
#                                                       'AT',
#                                                       'BE',
#                                                       'BO',
#                                                       'BR',
#                                                       'BG',
#                                                       'CA',
#                                                       'CL',
#                                                       'CO',
#                                                       'CR',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DK',
#                                                       'DO',
#                                                       'DE',
#                                                       'EC',
#                                                       'EE',
#                                                       'SV',
#                                                       'FI',
#                                                       'FR',
#                                                       'GR',
#                                                       'GT',
#                                                       'HN',
#                                                       'HK',
#                                                       'HU',
#                                                       'IS',
#                                                       'IE',
#                                                       'IT',
#                                                       'LV',
#                                                       'LT',
#                                                       'LU',
#                                                       'MY',
#                                                       'MT',
#                                                       'MX',
#                                                       'NL',
#                                                       'NZ',
#                                                       'NI',
#                                                       'NO',
#                                                       'PA',
#                                                       'PY',
#                                                       'PE',
#                                                       'PH',
#                                                       'PL',
#                                                       'PT',
#                                                       'SG',
#                                                       'SK',
#                                                       'ES',
#                                                       'SE',
#                                                       'CH',
#                                                       'TW',
#                                                       'TR',
#                                                       'UY',
#                                                       'US',
#                                                       'GB',
#                                                       'AD',
#                                                       'LI',
#                                                       'MC',
#                                                       'ID',
#                                                       'JP',
#                                                       'TH',
#                                                       'VN',
#                                                       'RO',
#                                                       'IL',
#                                                       'ZA',
#                                                       'SA',
#                                                       'AE',
#                                                       'BH',
#                                                       'QA',
#                                                       'OM',
#                                                       'KW',
#                                                       'EG',
#                                                       'MA',
#                                                       'DZ',
#                                                       'TN',
#                                                       'LB',
#                                                       'JO',
#                                                       'PS',
#                                                       'IN',
#                                                       'BY',
#                                                       'KZ',
#                                                       'MD',
#                                                       'UA',
#                                                       'AL',
#                                                       'BA',
#                                                       'HR',
#                                                       'ME',
#                                                       'MK',
#                                                       'RS',
#                                                       'SI',
#                                                       'KR',
#                                                       'BD',
#                                                       'PK',
#                                                       'LK',
#                                                       'GH',
#                                                       'KE',
#                                                       'NG',
#                                                       'TZ',
#                                                       'UG',
#                                                       'AG',
#                                                       'AM',
#                                                       'BS',
#                                                       'BB',
#                                                       'BZ',
#                                                       'BT',
#                                                       'BW',
#                                                       'BF',
#                                                       'CV',
#                                                       'CW',
#                                                       'DM',
#                                                       'FJ',
#                                                       'GM',
#                                                       'GE',
#                                                       'GD',
#                                                       'GW',
#                                                       'GY',
#                                                       'HT',
#                                                       'JM',
#                                                       'KI',
#                                                       'LS',
#                                                       'LR',
#                                                       'MW',
#                                                       'MV',
#                                                       'ML',
#                                                       'MH',
#                                                       'FM',
#                                                       'NA',
#                                                       'NR',
#                                                       'NE',
#                                                       'PW',
#                                                       'PG',
#                                                       'WS',
#                                                       'SM',
#                                                       'ST',
#                                                       'SN',
#                                                       'SC',
#                                                       'SL',
#                                                       'SB',
#                                                       'KN',
#                                                       'LC',
#                                                       'VC',
#                                                       'SR',
#                                                       'TL',
#                                                       'TO',
#                                                       'TT',
#                                                       'TV',
#                                                       'VU',
#                                                       'AZ',
#                                                       'BN',
#                                                       'BI',
#                                                       'KH',
#                                                       'CM',
#                                                       'TD',
#                                                       'KM',
#                                                       'GQ',
#                                                       'SZ',
#                                                       'GA',
#                                                       'GN',
#                                                       'KG',
#                                                       'LA',
#                                                       'MO',
#                                                       'MR',
#                                                       'MN',
#                                                       'NP',
#                                                       'RW',
#                                                       'TG',
#                                                       'UZ',
#                                                       'ZW',
#                                                       'BJ',
#                                                       'MG',
#                                                       'MU',
#                                                       'MZ',
#                                                       'AO',
#                                                       'CI',
#                                                       'DJ',
#                                                       'ZM',
#                                                       'CD',
#                                                       'CG',
#                                                       'IQ',
#                                                       'LY',
#                                                       'TJ',
#                                                       'VE',
#                                                       'ET',
#                                                       'XK'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0xzScN8P3hQAz3BT3YYX5w'},
#                                 'href': 'https://api.spotify.com/v1/albums/0xzScN8P3hQAz3BT3YYX5w',
#                                 'id': '0xzScN8P3hQAz3BT3YYX5w',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273c820f033bd82bef4355d1563',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02c820f033bd82bef4355d1563',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851c820f033bd82bef4355d1563',
#                                             'width': 64}],
#                                 'name': 'Shawn Mendes (Deluxe)',
#                                 'release_date': '2019-06-19',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0xzScN8P3hQAz3BT3YYX5w'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#                                    'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#                                    'id': '7n2wHs1TKAczGzO7Dd2rGr',
#                                    'name': 'Shawn Mendes',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#                       'available_markets': ['AR',
#                                             'AU',
#                                             'AT',
#                                             'BE',
#                                             'BO',
#                                             'BR',
#                                             'BG',
#                                             'CA',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DK',
#                                             'DO',
#                                             'DE',
#                                             'EC',
#                                             'EE',
#                                             'SV',
#                                             'FI',
#                                             'FR',
#                                             'GR',
#                                             'GT',
#                                             'HN',
#                                             'HK',
#                                             'HU',
#                                             'IS',
#                                             'IE',
#                                             'IT',
#                                             'LV',
#                                             'LT',
#                                             'LU',
#                                             'MY',
#                                             'MT',
#                                             'MX',
#                                             'NL',
#                                             'NZ',
#                                             'NI',
#                                             'NO',
#                                             'PA',
#                                             'PY',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PT',
#                                             'SG',
#                                             'SK',
#                                             'ES',
#                                             'SE',
#                                             'CH',
#                                             'TW',
#                                             'TR',
#                                             'UY',
#                                             'US',
#                                             'GB',
#                                             'AD',
#                                             'LI',
#                                             'MC',
#                                             'ID',
#                                             'JP',
#                                             'TH',
#                                             'VN',
#                                             'RO',
#                                             'IL',
#                                             'ZA',
#                                             'SA',
#                                             'AE',
#                                             'BH',
#                                             'QA',
#                                             'OM',
#                                             'KW',
#                                             'EG',
#                                             'MA',
#                                             'DZ',
#                                             'TN',
#                                             'LB',
#                                             'JO',
#                                             'PS',
#                                             'IN',
#                                             'BY',
#                                             'KZ',
#                                             'MD',
#                                             'UA',
#                                             'AL',
#                                             'BA',
#                                             'HR',
#                                             'ME',
#                                             'MK',
#                                             'RS',
#                                             'SI',
#                                             'KR',
#                                             'BD',
#                                             'PK',
#                                             'LK',
#                                             'GH',
#                                             'KE',
#                                             'NG',
#                                             'TZ',
#                                             'UG',
#                                             'AG',
#                                             'AM',
#                                             'BS',
#                                             'BB',
#                                             'BZ',
#                                             'BT',
#                                             'BW',
#                                             'BF',
#                                             'CV',
#                                             'CW',
#                                             'DM',
#                                             'FJ',
#                                             'GM',
#                                             'GE',
#                                             'GD',
#                                             'GW',
#                                             'GY',
#                                             'HT',
#                                             'JM',
#                                             'KI',
#                                             'LS',
#                                             'LR',
#                                             'MW',
#                                             'MV',
#                                             'ML',
#                                             'MH',
#                                             'FM',
#                                             'NA',
#                                             'NR',
#                                             'NE',
#                                             'PW',
#                                             'PG',
#                                             'WS',
#                                             'SM',
#                                             'ST',
#                                             'SN',
#                                             'SC',
#                                             'SL',
#                                             'SB',
#                                             'KN',
#                                             'LC',
#                                             'VC',
#                                             'SR',
#                                             'TL',
#                                             'TO',
#                                             'TT',
#                                             'TV',
#                                             'VU',
#                                             'AZ',
#                                             'BN',
#                                             'BI',
#                                             'KH',
#                                             'CM',
#                                             'TD',
#                                             'KM',
#                                             'GQ',
#                                             'SZ',
#                                             'GA',
#                                             'GN',
#                                             'KG',
#                                             'LA',
#                                             'MO',
#                                             'MR',
#                                             'MN',
#                                             'NP',
#                                             'RW',
#                                             'TG',
#                                             'UZ',
#                                             'ZW',
#                                             'BJ',
#                                             'MG',
#                                             'MU',
#                                             'MZ',
#                                             'AO',
#                                             'CI',
#                                             'DJ',
#                                             'ZM',
#                                             'CD',
#                                             'CG',
#                                             'IQ',
#                                             'LY',
#                                             'TJ',
#                                             'VE',
#                                             'ET',
#                                             'XK'],
#                       'disc_number': 1,
#                       'duration_ms': 191466,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USUM71907349'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/2bT1PH7Cw3J9p3t7nlXCdh'},
#                       'href': 'https://api.spotify.com/v1/tracks/2bT1PH7Cw3J9p3t7nlXCdh',
#                       'id': '2bT1PH7Cw3J9p3t7nlXCdh',
#                       'is_local': False,
#                       'name': "If I Can't Have You",
#                       'popularity': 73,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:2bT1PH7Cw3J9p3t7nlXCdh'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-09-03T13:31:00Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                          'href': 'https://api.spotify.com/v1/users/',
#                          'id': '',
#                          'type': 'user',
#                          'uri': 'spotify:user:'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#                                              'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#                                              'id': '06HL4z0CvFAxyc27GXpf02',
#                                              'name': 'Taylor Swift',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#                                 'available_markets': ['AR',
#                                                       'AU',
#                                                       'AT',
#                                                       'BE',
#                                                       'BO',
#                                                       'BR',
#                                                       'BG',
#                                                       'CA',
#                                                       'CL',
#                                                       'CO',
#                                                       'CR',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DK',
#                                                       'DO',
#                                                       'DE',
#                                                       'EC',
#                                                       'EE',
#                                                       'SV',
#                                                       'FI',
#                                                       'FR',
#                                                       'GR',
#                                                       'GT',
#                                                       'HN',
#                                                       'HK',
#                                                       'HU',
#                                                       'IS',
#                                                       'IE',
#                                                       'IT',
#                                                       'LV',
#                                                       'LT',
#                                                       'LU',
#                                                       'MY',
#                                                       'MT',
#                                                       'MX',
#                                                       'NL',
#                                                       'NZ',
#                                                       'NI',
#                                                       'NO',
#                                                       'PA',
#                                                       'PY',
#                                                       'PE',
#                                                       'PH',
#                                                       'PL',
#                                                       'PT',
#                                                       'SG',
#                                                       'SK',
#                                                       'ES',
#                                                       'SE',
#                                                       'CH',
#                                                       'TW',
#                                                       'TR',
#                                                       'UY',
#                                                       'US',
#                                                       'GB',
#                                                       'AD',
#                                                       'LI',
#                                                       'MC',
#                                                       'ID',
#                                                       'JP',
#                                                       'TH',
#                                                       'VN',
#                                                       'RO',
#                                                       'IL',
#                                                       'ZA',
#                                                       'SA',
#                                                       'AE',
#                                                       'BH',
#                                                       'QA',
#                                                       'OM',
#                                                       'KW',
#                                                       'EG',
#                                                       'MA',
#                                                       'DZ',
#                                                       'TN',
#                                                       'LB',
#                                                       'JO',
#                                                       'PS',
#                                                       'IN',
#                                                       'BY',
#                                                       'KZ',
#                                                       'MD',
#                                                       'UA',
#                                                       'AL',
#                                                       'BA',
#                                                       'HR',
#                                                       'ME',
#                                                       'MK',
#                                                       'RS',
#                                                       'SI',
#                                                       'KR',
#                                                       'BD',
#                                                       'PK',
#                                                       'LK',
#                                                       'GH',
#                                                       'KE',
#                                                       'NG',
#                                                       'TZ',
#                                                       'UG',
#                                                       'AG',
#                                                       'AM',
#                                                       'BS',
#                                                       'BB',
#                                                       'BZ',
#                                                       'BT',
#                                                       'BW',
#                                                       'BF',
#                                                       'CV',
#                                                       'CW',
#                                                       'DM',
#                                                       'FJ',
#                                                       'GM',
#                                                       'GE',
#                                                       'GD',
#                                                       'GW',
#                                                       'GY',
#                                                       'HT',
#                                                       'JM',
#                                                       'KI',
#                                                       'LS',
#                                                       'LR',
#                                                       'MW',
#                                                       'MV',
#                                                       'ML',
#                                                       'MH',
#                                                       'FM',
#                                                       'NA',
#                                                       'NR',
#                                                       'NE',
#                                                       'PW',
#                                                       'PG',
#                                                       'WS',
#                                                       'SM',
#                                                       'ST',
#                                                       'SN',
#                                                       'SC',
#                                                       'SL',
#                                                       'SB',
#                                                       'KN',
#                                                       'LC',
#                                                       'VC',
#                                                       'SR',
#                                                       'TL',
#                                                       'TO',
#                                                       'TT',
#                                                       'TV',
#                                                       'VU',
#                                                       'AZ',
#                                                       'BN',
#                                                       'BI',
#                                                       'KH',
#                                                       'CM',
#                                                       'TD',
#                                                       'KM',
#                                                       'GQ',
#                                                       'SZ',
#                                                       'GA',
#                                                       'GN',
#                                                       'KG',
#                                                       'LA',
#                                                       'MO',
#                                                       'MR',
#                                                       'MN',
#                                                       'NP',
#                                                       'RW',
#                                                       'TG',
#                                                       'UZ',
#                                                       'ZW',
#                                                       'BJ',
#                                                       'MG',
#                                                       'MU',
#                                                       'MZ',
#                                                       'AO',
#                                                       'CI',
#                                                       'DJ',
#                                                       'ZM',
#                                                       'CD',
#                                                       'CG',
#                                                       'IQ',
#                                                       'LY',
#                                                       'TJ',
#                                                       'VE',
#                                                       'ET',
#                                                       'XK'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#                                 'href': 'https://api.spotify.com/v1/albums/1NAmidJlEaVgA3MpcPFYGq',
#                                 'id': '1NAmidJlEaVgA3MpcPFYGq',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273e787cffec20aa2a396a61647',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647',
#                                             'width': 64}],
#                                 'name': 'Lover',
#                                 'release_date': '2019-08-23',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 18,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1NAmidJlEaVgA3MpcPFYGq'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#                                    'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#                                    'id': '06HL4z0CvFAxyc27GXpf02',
#                                    'name': 'Taylor Swift',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#                       'available_markets': ['AR',
#                                             'AU',
#                                             'AT',
#                                             'BE',
#                                             'BO',
#                                             'BR',
#                                             'BG',
#                                             'CA',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DK',
#                                             'DO',
#                                             'DE',
#                                             'EC',
#                                             'EE',
#                                             'SV',
#                                             'FI',
#                                             'FR',
#                                             'GR',
#                                             'GT',
#                                             'HN',
#                                             'HK',
#                                             'HU',
#                                             'IS',
#                                             'IE',
#                                             'IT',
#                                             'LV',
#                                             'LT',
#                                             'LU',
#                                             'MY',
#                                             'MT',
#                                             'MX',
#                                             'NL',
#                                             'NZ',
#                                             'NI',
#                                             'NO',
#                                             'PA',
#                                             'PY',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PT',
#                                             'SG',
#                                             'SK',
#                                             'ES',
#                                             'SE',
#                                             'CH',
#                                             'TW',
#                                             'TR',
#                                             'UY',
#                                             'US',
#                                             'GB',
#                                             'AD',
#                                             'LI',
#                                             'MC',
#                                             'ID',
#                                             'JP',
#                                             'TH',
#                                             'VN',
#                                             'RO',
#                                             'IL',
#                                             'ZA',
#                                             'SA',
#                                             'AE',
#                                             'BH',
#                                             'QA',
#                                             'OM',
#                                             'KW',
#                                             'EG',
#                                             'MA',
#                                             'DZ',
#                                             'TN',
#                                             'LB',
#                                             'JO',
#                                             'PS',
#                                             'IN',
#                                             'BY',
#                                             'KZ',
#                                             'MD',
#                                             'UA',
#                                             'AL',
#                                             'BA',
#                                             'HR',
#                                             'ME',
#                                             'MK',
#                                             'RS',
#                                             'SI',
#                                             'KR',
#                                             'BD',
#                                             'PK',
#                                             'LK',
#                                             'GH',
#                                             'KE',
#                                             'NG',
#                                             'TZ',
#                                             'UG',
#                                             'AG',
#                                             'AM',
#                                             'BS',
#                                             'BB',
#                                             'BZ',
#                                             'BT',
#                                             'BW',
#                                             'BF',
#                                             'CV',
#                                             'CW',
#                                             'DM',
#                                             'FJ',
#                                             'GM',
#                                             'GE',
#                                             'GD',
#                                             'GW',
#                                             'GY',
#                                             'HT',
#                                             'JM',
#                                             'KI',
#                                             'LS',
#                                             'LR',
#                                             'MW',
#                                             'MV',
#                                             'ML',
#                                             'MH',
#                                             'FM',
#                                             'NA',
#                                             'NR',
#                                             'NE',
#                                             'PW',
#                                             'PG',
#                                             'WS',
#                                             'SM',
#                                             'ST',
#                                             'SN',
#                                             'SC',
#                                             'SL',
#                                             'SB',
#                                             'KN',
#                                             'LC',
#                                             'VC',
#                                             'SR',
#                                             'TL',
#                                             'TO',
#                                             'TT',
#                                             'TV',
#                                             'VU',
#                                             'AZ',
#                                             'BN',
#                                             'BI',
#                                             'KH',
#                                             'CM',
#                                             'TD',
#                                             'KM',
#                                             'GQ',
#                                             'SZ',
#                                             'GA',
#                                             'GN',
#                                             'KG',
#                                             'LA',
#                                             'MO',
#                                             'MR',
#                                             'MN',
#                                             'NP',
#                                             'RW',
#                                             'TG',
#                                             'UZ',
#                                             'ZW',
#                                             'BJ',
#                                             'MG',
#                                             'MU',
#                                             'MZ',
#                                             'AO',
#                                             'CI',
#                                             'DJ',
#                                             'ZM',
#                                             'CD',
#                                             'CG',
#                                             'IQ',
#                                             'LY',
#                                             'TJ',
#                                             'VE',
#                                             'ET',
#                                             'XK'],
#                       'disc_number': 1,
#                       'duration_ms': 178426,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USUG11901472'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr'},
#                       'href': 'https://api.spotify.com/v1/tracks/1BxfuPKGuaTgP7aM0Bbdwr',
#                       'id': '1BxfuPKGuaTgP7aM0Bbdwr',
#                       'is_local': False,
#                       'name': 'Cruel Summer',
#                       'popularity': 95,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
# ...
#                                                       'ML',
#                                                       'MH',
#                                                       'FM',
#                                                       'NA',
#                                                       'NR',
#                                                       'NE',
#                                                       'PW',
#                                                       'PG',
#                                                       'PR',
#                                                       'WS',
#                                                       'SM',
#                                                       'ST',
#                                                       'SN',
#                                                       'SC',
#                                                       'SL',
#                                                       'SB',
#                                                       'KN',
#                                                       'LC',
#                                                       'VC',
#                                                       'SR',
#                                                       'TL',
#                                                       'TO',
#                                                       'TT',
#                                                       'TV',
#                                                       'VU',
#                                                       'AZ',
#                                                       'BN',
#                                                       'BI',
#                                                       'KH',
#                                                       'CM',
#                                                       'TD',
#                                                       'KM',
#                                                       'GQ',
#                                                       'SZ',
#                                                       'GA',
#                                                       'GN',
#                                                       'KG',
#                                                       'LA',
#                                                       'MO',
#                                                       'MR',
#                                                       'MN',
#                                                       'NP',
#                                                       'RW',
#                                                       'TG',
#                                                       'UZ',
#                                                       'ZW',
#                                                       'BJ',
#                                                       'MG',
#                                                       'MU',
#                                                       'MZ',
#                                                       'AO',
#                                                       'CI',
#                                                       'DJ',
#                                                       'ZM',
#                                                       'CD',
#                                                       'CG',
#                                                       'IQ',
#                                                       'LY',
#                                                       'TJ',
#                                                       'VE',
#                                                       'ET',
#                                                       'XK'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/493HYe7N5pleudEZRyhE7R'},
#                                 'href': 'https://api.spotify.com/v1/albums/493HYe7N5pleudEZRyhE7R',
#                                 'id': '493HYe7N5pleudEZRyhE7R',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273d5a8395b0d80b8c48a5d851c',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02d5a8395b0d80b8c48a5d851c',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851d5a8395b0d80b8c48a5d851c',
#                                             'width': 64}],
#                                 'name': 'All I Want Is You',
#                                 'release_date': '2010-11-26',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 13,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:493HYe7N5pleudEZRyhE7R'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/360IAlyVv4PCEVjgyMZrxK'},
#                                    'href': 'https://api.spotify.com/v1/artists/360IAlyVv4PCEVjgyMZrxK',
#                                    'id': '360IAlyVv4PCEVjgyMZrxK',
#                                    'name': 'Miguel',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:360IAlyVv4PCEVjgyMZrxK'}],
#                       'available_markets': ['AR',
#                                             'AU',
#                                             'AT',
#                                             'BE',
#                                             'BO',
#                                             'BR',
#                                             'BG',
#                                             'CA',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DK',
#                                             'DO',
#                                             'DE',
#                                             'EC',
#                                             'EE',
#                                             'SV',
#                                             'FI',
#                                             'FR',
#                                             'GR',
#                                             'GT',
#                                             'HN',
#                                             'HK',
#                                             'HU',
#                                             'IS',
#                                             'IE',
#                                             'IT',
#                                             'LV',
#                                             'LT',
#                                             'LU',
#                                             'MY',
#                                             'MT',
#                                             'MX',
#                                             'NL',
#                                             'NZ',
#                                             'NI',
#                                             'NO',
#                                             'PA',
#                                             'PY',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PT',
#                                             'SG',
#                                             'SK',
#                                             'ES',
#                                             'SE',
#                                             'CH',
#                                             'TW',
#                                             'TR',
#                                             'UY',
#                                             'US',
#                                             'GB',
#                                             'AD',
#                                             'LI',
#                                             'MC',
#                                             'ID',
#                                             'JP',
#                                             'TH',
#                                             'VN',
#                                             'RO',
#                                             'IL',
#                                             'ZA',
#                                             'SA',
#                                             'AE',
#                                             'BH',
#                                             'QA',
#                                             'OM',
#                                             'KW',
#                                             'EG',
#                                             'MA',
#                                             'DZ',
#                                             'TN',
#                                             'LB',
#                                             'JO',
#                                             'PS',
#                                             'IN',
#                                             'BY',
#                                             'KZ',
#                                             'MD',
#                                             'UA',
#                                             'AL',
#                                             'BA',
#                                             'HR',
#                                             'ME',
#                                             'MK',
#                                             'RS',
#                                             'SI',
#                                             'KR',
#                                             'BD',
#                                             'PK',
#                                             'LK',
#                                             'GH',
#                                             'KE',
#                                             'NG',
#                                             'TZ',
#                                             'UG',
#                                             'AG',
#                                             'AM',
#                                             'BS',
#                                             'BB',
#                                             'BZ',
#                                             'BT',
#                                             'BW',
#                                             'BF',
#                                             'CV',
#                                             'CW',
#                                             'DM',
#                                             'FJ',
#                                             'GM',
#                                             'GE',
#                                             'GD',
#                                             'GW',
#                                             'GY',
#                                             'HT',
#                                             'JM',
#                                             'KI',
#                                             'LS',
#                                             'LR',
#                                             'MW',
#                                             'MV',
#                                             'ML',
#                                             'MH',
#                                             'FM',
#                                             'NA',
#                                             'NR',
#                                             'NE',
#                                             'PW',
#                                             'PG',
#                                             'PR',
#                                             'WS',
#                                             'SM',
#                                             'ST',
#                                             'SN',
#                                             'SC',
#                                             'SL',
#                                             'SB',
#                                             'KN',
#                                             'LC',
#                                             'VC',
#                                             'SR',
#                                             'TL',
#                                             'TO',
#                                             'TT',
#                                             'TV',
#                                             'VU',
#                                             'AZ',
#                                             'BN',
#                                             'BI',
#                                             'KH',
#                                             'CM',
#                                             'TD',
#                                             'KM',
#                                             'GQ',
#                                             'SZ',
#                                             'GA',
#                                             'GN',
#                                             'KG',
#                                             'LA',
#                                             'MO',
#                                             'MR',
#                                             'MN',
#                                             'NP',
#                                             'RW',
#                                             'TG',
#                                             'UZ',
#                                             'ZW',
#                                             'BJ',
#                                             'MG',
#                                             'MU',
#                                             'MZ',
#                                             'AO',
#                                             'CI',
#                                             'DJ',
#                                             'ZM',
#                                             'CD',
#                                             'CG',
#                                             'IQ',
#                                             'LY',
#                                             'TJ',
#                                             'VE',
#                                             'ET',
#                                             'XK'],
#                       'disc_number': 1,
#                       'duration_ms': 195373,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10800160'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0JXXNGljqupsJaZsgSbMZV'},
#                       'href': 'https://api.spotify.com/v1/tracks/0JXXNGljqupsJaZsgSbMZV',
#                       'id': '0JXXNGljqupsJaZsgSbMZV',
#                       'is_local': False,
#                       'name': 'Sure Thing',
#                       'popularity': 85,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/d337faa4bb71c8ac9a13998be64fbb0d7d8b8463?cid=86e945fdcd5641c7afc4daa8d38af085',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:0JXXNGljqupsJaZsgSbMZV'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX7iB3RCnBnN4/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 626}

# %%
track_info = playlist_info['tracks']['items'][0]['track']

# %%
# Out:
# list

# %%
# Now, let's get a list of the info for all the tracks in the playlist

# create a variable with an empty list
playlist_tracks_info = []

# get the tracks info from the playlist data
playlist_items = playlist_info['tracks']['items']

# make sure it's a list so that we can iterate over it
type(playlist_items)

# for every track info in the playlist
for playlist_item in playlist_items:
    # get the track info using the funciton we wrote a few cells above
    item_info = get_track_info(playlist_item['track'])
    # add the formatted info to the list
    playlist_tracks_info.append(item_info)

# %%
# let's see the results!
playlist_tracks_info
# Out:
# [{'artists': ['Shawn Mendes'],
#   'id': '2bT1PH7Cw3J9p3t7nlXCdh',
#   'name': "If I Can't Have You",
#   'release_year': '2019',
#   'spotify_url': 'https://open.spotify.com/track/2bT1PH7Cw3J9p3t7nlXCdh'}]

# %%
# This is how you can do the same thing using list comprehension. It is a Python code structure allowing for creating new lists or dictionaries
# based on existing iterables, while iterating. It is similar to a reversed "for" loop structure.
# You'd often split it into lines for readibility.

# More info on list comprehension:
# https://www.w3schools.com/python/python_lists_comprehension.asp
playlist_tracks_info = [
    get_track_info(playlist_item['track'])
    for playlist_item in playlist_items
]

# %%
# Now that we have a list of organised data, let's make it into a Pandas DataFrame
import pandas as pd

playlist_df = pd.DataFrame(playlist_tracks_info)

# This displays the first 5 rows - the "head" method allows you to preview the data easily without scrolling
playlist_df.head()
# Out:
#             artists                      id                        name  \
# 0    [Shawn Mendes]  2bT1PH7Cw3J9p3t7nlXCdh         If I Can't Have You
# 1    [Taylor Swift]  1BxfuPKGuaTgP7aM0Bbdwr                Cruel Summer
# 2     [girl in red]  6IPwKM3fUUzlElbvKw2sKl  we fell in love in october
# 3  [Arctic Monkeys]  5XeFesFbtLpXzIVDNQP22n            I Wanna Be Yours
# 4        [Doja Cat]  4dHRp03oxqJQfjGU8ECo7v          Paint The Town Red
#
#   release_year                                        spotify_url
# 0         2019  https://open.spotify.com/track/2bT1PH7Cw3J9p3t...
# 1         2019  https://open.spotify.com/track/1BxfuPKGuaTgP7a...
# 2         2018  https://open.spotify.com/track/6IPwKM3fUUzlElb...
# 3         2013  https://open.spotify.com/track/5XeFesFbtLpXzIV...
# 4         2023  https://open.spotify.com/track/4dHRp03oxqJQfjG...

# %%
# Here's how you can save it to a csv file. It should appear in the same directory as the notebook.
playlist_df.to_csv('my_playlist.csv')

# %%
# And if you want to save it to an Excel spreadsheet:
# playlist_df.to_excel('my_playlist.xlsx')

# %%
# Now let's try saving some data to the database. Please make sure you have mongo running. You should be able to see the db server running if you run "mongosh" from the console
import pymongo

# this should eb the default address but you may want to cross-check it with what Mongo Shell is displaying
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
# access the database calledd "musicDB"
music_db = mongo_client['musicDB']

# %%
# let's get info about the first track in the playlist. This will return a pd.Series object
song_info = playlist_df.iloc[0]

# %%
# We can bring it back to the dict format to 
song_dict = song_info.to_dict()

# %%
song_dict
# Out:
# {'artists': ['Shawn Mendes'],
#  'id': '2bT1PH7Cw3J9p3t7nlXCdh',
#  'name': "If I Can't Have You",
#  'release_year': '2019',
#  'spotify_url': 'https://open.spotify.com/track/2bT1PH7Cw3J9p3t7nlXCdh'}

# %%
music_db['SongInfo'].insert_one(song_dict)
# Out:
# InsertOneResult(ObjectId('66337565de92b49e696ced2a'), acknowledged=True)

# %%
music_db['SongInfo'].find_one()
# Out:
# {'_id': ObjectId('66337565de92b49e696ced2a'),
#  'artists': ['Shawn Mendes'],
#  'id': '2bT1PH7Cw3J9p3t7nlXCdh',
#  'name': "If I Can't Have You",
#  'release_year': '2019',
#  'spotify_url': 'https://open.spotify.com/track/2bT1PH7Cw3J9p3t7nlXCdh'}

# %%
sp.audio_features(TRACK_ID)
# Out:
# [{'danceability': 0.566,
#   'energy': 0.366,
#   'key': 7,
#   'loudness': -12.808,
#   'mode': 1,
#   'speechiness': 0.028,
#   'acousticness': 0.113,
#   'instrumentalness': 0.181,
#   'liveness': 0.155,
#   'valence': 0.237,
#   'tempo': 129.96,
#   'type': 'audio_features',
#   'id': '6IPwKM3fUUzlElbvKw2sKl',
#   'uri': 'spotify:track:6IPwKM3fUUzlElbvKw2sKl',
#   'track_href': 'https://api.spotify.com/v1/tracks/6IPwKM3fUUzlElbvKw2sKl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6IPwKM3fUUzlElbvKw2sKl',
#   'duration_ms': 184154,
#   'time_signature': 4}]
