# %%
# import the MongoClient class from the pymongo library
from pymongo import MongoClient

# %%
# if you don't have pymongon installed, install it:
#!pip install pymongo

# %%
client = MongoClient("localhost", 27017)

# %%
db = client["BigDataDB"]

# %%
collection_names = db.list_collection_names()

# %%
collection_names
# Out:
# ['students', 'testCollection']

# %%
# display collection contents
cursor = db.testCollection.find()

# %%
myclient = MongoClient("mongodb://localhost:27017/")
mydb = myclient["BigDataDB"]
mycol = mydb["students"]

mydict = { "name": "John", "address": "Highway 37" }

x = mycol.insert_one(mydict)

# %%
db.students.find_one()
# Out:
# {'_id': ObjectId('6617c5405dbad9386216c9b5'),
#  'first_name': 'Jacob',
#  'last_name': 'Stenton'}

# %%
[x for x in mycol.find()]
# Out:
# [{'_id': ObjectId('6617c5405dbad9386216c9b5'),
#   'first_name': 'Jacob',
#   'last_name': 'Stenton'},
#  {'_id': ObjectId('6617ca79bc244825508fb979'),
#   'name': 'John',
#   'address': 'Highway 37'},
#  {'_id': ObjectId('6617cab5bc244825508fb97b'),
#   'name': 'John',
#   'address': 'Highway 37'}]

# %%
# to learn more about what we can do with this library
help(db)
# Out:
# Help on Database in module pymongo.database object:
#
# class Database(pymongo.common.BaseObject, typing.Generic)
#  |  Database(client: 'MongoClient[_DocumentType]', name: 'str', codec_options: 'Optional[bson.CodecOptions[_DocumentTypeArg]]' = None, read_preference: 'Optional[_ServerMode]' = None, write_concern: 'Optional[WriteConcern]' = None, read_concern: 'Optional[ReadConcern]' = None) -> 'None'
#  |
#  |  A Mongo database.
#  |
#  |  Method resolution order:
#  |      Database
#  |      pymongo.common.BaseObject
#  |      typing.Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self) -> 'NoReturn'
#  |
#  |  __eq__(self, other: 'Any') -> 'bool'
#  |      Return self==value.
#  |
#  |  __getattr__(self, name: 'str') -> 'Collection[_DocumentType]'
#  |      Get a collection of this database by name.
#  |
#  |      Raises InvalidName if an invalid collection name is used.
#  |
#  |      :Parameters:
# ...
