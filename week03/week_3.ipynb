# %%
from bs4 import BeautifulSoup
import requests
import random

# %% [markdown]
# # Recaps

# %% [markdown]
# ## HTTP
#
# A [Hypertext Transfer Protocol (HTTP)](https://en.wikipedia.org/wiki/HTTP) request is made by a client, to a named host, which is located on a server.
#
# A HTTP request contains the following elements:
# - A request line.
# - A series of HTTP headers, or header fields.
# - A message body, if needed. which is usually a JavaScript [Object Notation (JSON)](https://www.w3schools.com/js/js_json_objects.asp)
#
# HTTP request methods
# GET
# POST
# PUT
# DELETE
#
# [and more ...](https://developer.mozilla.org/en-US/docs/Web/HTTP/Methods)
#
# Example Request
# <img src="https://developer.mozilla.org/en-US/docs/Web/HTTP/Overview/http_request.png"/>
#
# Example Reponse
# <img src="https://developer.mozilla.org/en-US/docs/Web/HTTP/Overview/http_response.png"/>
#
# The HTTP Response will have :
# - A [status code](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status), indicating if the request was successful or not, and why.
# - A status message, a non-authoritative short description of the status code.
# - HTTP headers, like those for requests.
# - Optionally, a body containing the fetched resource which can be a blob or a JSON object aswell

# %% [markdown]
# ## Databases
#
# <img src="https://images.prismic.io/nightborn/7e215705-8aa6-4ff4-94bf-5a6a801b92a4_thumbnail_website2.jpg?auto=compress,format"/>
#
# One of the most common databases is a :
#
# <b>Relational Database management system (RDMS) or simply relation Databases:</b> is a collection that organizes data in predefined relationships where data is stored in one or more tables columns and rows
# - Structured Query Language(SQL), is a domain-specific language used in programming and managing of data held in a relational database. https://www.w3schools.com/sql/
#
# Some examples include
# - Microsoft SQL Server
# - MySQL
# - PostgreSQL
# - SQLite
# - Oracle Database
# - MariaDB
#
#
# <b>[NoSQL](https://www.couchbase.com/resources/why-nosql/) database:</b>  stores information in JSON documents instead of columns and rows used by relational databases. NoSQL stands for “not only SQL” rather than “no SQL” at all. Types of NoSql Databases include
# - Document databases
# - Key-value stores
# - Wide-column databases
# - Graph databases
#
# Some examples include:
# - MongoDB
# - Apache Cassandra
# - Couchbase
# - Amazon DynamoDB
# - Redis
# - Neo4j

# %% [markdown]
# # Web Crawling
#
# The goal of this notebook is to go to a Wikipedia page,
#  - scrape all the links from this page,
#   - store them somehow
#   - pick a link at random to perform the same process again.
# This will repeat for a set number of iterations, but could run infinitely in theory.. until something crashes.
#
# This is to introduce you to some concepts behind web-crawling - perhaps it will stimulate some ideas about how you might make a more directed and intentional web-crawler with some specific goal in mind...
#
# The first thing to do is get an idea of what we are working with. Going to some random Wikipedia article (in this case.. chicken) we can see a few things:
#
#
# 1. The URLs are of the form `https://en.wikipedia.org/wiki/Chicken` - which is convenient and neat.
# 2. The HTML markup also seems quite neat and links are in clear `<a>` tags.
# 3. Links to other Wikipedia articles seem to be of the shortened form `/wiki/Domestication` (as seen in the pic).
# 4. There are _a lot_ of links on a page.
#
# > If you didn't know, all I did in the pic above is just right click on a link and click `Inspect` - this opens up the console and expands the HTML to reveal the specific tag you are _inspecting_. This is really handy. I'm using Firefox but I'd imagine all good browsers (...Firefox or Chrome) have this feature.

# %% [markdown]
# ## Getting Started
#
# As with any task, you need to break it down into manageable chunks as soon as possible. First of all I want to make sure I can make a HTTP request to a Github page and retrieve the page content.
#
# I'll be using the [Requests](https://docs.python-requests.org/en/latest/) package today, but [URLLib](https://docs.python.org/3/library/urllib.html) would also work. They pretty much do the same thing, but it seems Requests is used more often and is a slightly nicer package to use.

# %%
query = 'chicken'

url = 'https://en.wikipedia.org/wiki/' + query
page = requests.get(url)
soup = BeautifulSoup(page.content, features="html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Chicken - Wikipedia</title>
# <script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split('%2C').forEach(function(pref){className=className.replace(new RegExp('(^| )'+pref.replace(/-clientpref-\w+$|[^\w-]+/g,'')+'-clientpref-\\w+( |$)'),'$1'+pref+'$2');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],
# "wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"713c5f4a-9e9a-44f0-a999-db21fd24dc8a","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Chicken","wgTitle":"Chicken","wgCurRevisionId":1209576901,"wgRevisionId":1209576901,"wgArticleId":37402,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template wayback links","All articles with dead external links","Articles with dead external links from February 2022","Articles with permanently dead external links","Good articles","Articles with short description","Short description is different from Wikidata","Wikipedia indefinitely move-protected pages","Wikipedia indefinitely semi-protected pages","Use mdy dates from September 2023","Articles with 'species' microformats",
# "Articles containing potentially dated statements from 2018","All articles containing potentially dated statements","Commons category link is on Wikidata","Articles with BNF identifiers","Articles with BNFdata identifiers","Articles with GND identifiers","Articles with J9U identifiers","Articles with LCCN identifiers","Articles with NDL identifiers","Articles with NKC identifiers","Articles containing video clips","Domesticated animals","Chickens","Birds described in 1758","Bird common names","Taxa named by Carl Linnaeus","Junglefowls","Poultry","Subspecies","Cosmopolitan birds","National symbols of Kenya","Heraldic beasts"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Chicken","wgRelevantArticleId":37402,"wgIsProbablyEditable":false,"wgRelevantPageIsProbablyEditable":false,"wgRestrictionEdit":["autoconfirmed"],"wgRestrictionMove":["sysop"],"wgNoticeProject":"wikipedia","wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}
# },"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":70000,"wgULSCurrentAutonym":"English","wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q780","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands","fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};RLSTATE={"skins.vector.user.styles":"ready",
# "ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","skins.vector.user":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","mediawiki.page.gallery.styles":"ready","ext.tmh.player.styles":"ready","codex-search-styles":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","mediawiki.page.media","ext.tmh.player","site","mediawiki.page.ready","jquery.makeCollapsible","mediawiki.toc","skins.vector.js","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.switcher","ext.urlShortener.toolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init",
# "ext.visualEditor.targetLoader","ext.echo.centralauth","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.cx.uls.quick.actions","wikibase.client.vector-2022","ext.checkUser.clientHints","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.impl(function(){return["user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# }];});});</script>
# <link href="/w/load.php?lang=en&amp;modules=codex-search-styles%7Cext.cite.styles%7Cext.tmh.player.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cmediawiki.page.gallery.styles%7Cskins.vector.icons%2Cstyles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector-2022"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector-2022" rel="stylesheet"/>
# <meta content="MediaWiki 1.42.0-wmf.20" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="max-image-preview:standard" name="robots"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/8/84/Male_and_female_chicken_sitting_together.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1602" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Male_and_female_chicken_sitting_together.jpg/800px-Male_and_female_chicken_sitting_together.jpg" property="og:image"/>
# <meta content="800" property="og:image:width"/>
# <meta content="1068" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Male_and_female_chicken_sitting_together.jpg/640px-Male_and_female_chicken_sitting_together.jpg" property="og:image"/>
# <meta content="640" property="og:image:width"/>
# <meta content="854" property="og:image:height"/>
# <meta content="width=1000" name="viewport"/>
# <meta content="Chicken - Wikipedia" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//en.m.wikipedia.org/wiki/Chicken" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://en.wikipedia.org/wiki/Chicken" rel="canonical"/>
# <link href="https://creativecommons.org/licenses/by-sa/4.0/deed.en" rel="license"/>
# <link href="/w/index.php?title=Special:RecentChanges&amp;feed=atom" rel="alternate" title="Wikipedia Atom feed" type="application/atom+xml"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch">
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </link></head>
# <body class="skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Chicken rootpage-Chicken skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Site" class="vector-main-menu-landmark" role="navigation">
# <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
# <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-main-menu-dropdown-checkbox" id="vector-main-menu-dropdown-label"><span class="vector-icon mw-ui-icon-menu mw-ui-icon-wikimedia-menu"></span>
# <span class="vector-dropdown-label-text">Main menu</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-unpinned-container" id="vector-main-menu-unpinned-container">
# <div class="vector-main-menu vector-pinnable-element" id="vector-main-menu">
# <div class="vector-pinnable-header vector-main-menu-pinnable-header vector-pinnable-header-unpinned" data-feature-name="main-menu-pinned" data-pinnable-element-id="vector-main-menu" data-pinned-container-id="vector-main-menu-pinned-container" data-unpinned-container-id="vector-main-menu-unpinned-container">
# <div class="vector-pinnable-header-label">Main menu</div>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-main-menu.pin">move to sidebar</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-main-menu.unpin">hide</button>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-navigation" id="p-navigation">
# <div class="vector-menu-heading">
# 		Navigation
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a></li><li class="mw-list-item" id="n-contents"><a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a></li><li class="mw-list-item" id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a></li><li class="mw-list-item" id="n-randompage"><a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a></li><li class="mw-list-item" id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a></li><li class="mw-list-item" id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a></li><li class="mw-list-item" id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation"><span>Donate</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-interaction" id="p-interaction">
# <div class="vector-menu-heading">
# 		Contribute
# 	</div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a></li><li class="mw-list-item" id="n-introduction"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a></li><li class="mw-list-item" id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors"><span>Community portal</span></a></li><li class="mw-list-item" id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]"><span>Recent changes</span></a></li><li class="mw-list-item" id="n-upload"><a href="/wiki/Wikipedia:File_upload_wizard" title="Add images or other media for use on Wikipedia"><span>Upload file</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-main-menu-action vector-main-menu-action-lang-alert">
# <div class="vector-main-menu-action-item">
# <div class="vector-main-menu-action-heading vector-menu-heading">Languages</div>
# <div class="vector-main-menu-action-content vector-menu-content">
# <div class="mw-message-box cdx-message cdx-message--block mw-message-box-notice cdx-message--notice vector-language-sidebar-alert"><span class="cdx-message__icon"></span><div class="cdx-message__content">Language links are at the top of the page.</div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <a class="mw-logo" href="/wiki/Main_Page">
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>
# <span class="mw-logo-container">
# <img alt="Wikipedia" class="mw-logo-wordmark" src="/static/images/mobile/copyright/wikipedia-wordmark-en.svg" style="width: 7.5em; height: 1.125em;"/>
# <img alt="The Free Encyclopedia" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-en.svg" style="width: 7.3125em; height: 0.8125em;" width="117"/>
# </span>
# </a>
# </div>
# <div class="vector-header-end">
# <div class="vector-search-box-vue vector-search-box-collapses vector-search-box-show-thumbnail vector-search-box-auto-expand-width vector-search-box" id="p-search" role="search">
# <a accesskey="f" class="cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only search-toggle" href="/wiki/Special:Search" id="" title="Search Wikipedia [f]"><span class="vector-icon mw-ui-icon-search mw-ui-icon-wikimedia-search"></span>
# <span>Search</span>
# </a>
# <div class="vector-typeahead-search-container">
# <div class="cdx-typeahead-search cdx-typeahead-search--show-thumbnail cdx-typeahead-search--auto-expand-width">
# <form action="/w/index.php" class="cdx-search-input cdx-search-input--has-end-button" id="searchform">
# <div class="cdx-search-input__input-wrapper" data-search-loc="header-moved" id="simpleSearch">
# <div class="cdx-text-input cdx-text-input--has-start-icon">
# <input accesskey="f" aria-label="Search Wikipedia" autocapitalize="sentences" class="cdx-text-input__input" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
# <span class="cdx-text-input__icon cdx-text-input__start-icon"></span>
# </div>
# <input name="title" type="hidden" value="Special:Search"/>
# </div>
# <button class="cdx-button cdx-search-input__end-button">Search</button>
# </form>
# </div>
# </div>
# </div>
# <nav aria-label="Personal tools" class="vector-user-links vector-user-links-wide" role="navigation">
# <div class="vector-user-links-main">
# <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-preferences">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-userpage">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# <nav aria-label="Appearance" class="vector-client-prefs-landmark">
# </nav>
# <div class="vector-menu mw-portlet emptyPortlet" id="p-vector-user-menu-notifications">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet" id="p-vector-user-menu-overflow">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-createaccount-2"><a class="" data-mw="interface" href="/w/index.php?title=Special:CreateAccount&amp;returnto=Chicken" title="You are encouraged to create an account and log in; however, it is not mandatory"><span>Create account</span></a>
# </li>
# <li class="user-links-collapsible-item mw-list-item user-links-collapsible-item" id="pt-login-2"><a accesskey="o" class="" data-mw="interface" href="/w/index.php?title=Special:UserLogin&amp;returnto=Chicken" title="You're encouraged to log in; however, it's not mandatory. [o]"><span>Log in</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="vector-dropdown vector-user-menu vector-button-flush-right vector-user-menu-logged-out" id="vector-user-links-dropdown" title="Log in and more options">
# <input aria-haspopup="true" aria-label="Personal tools" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-user-links-dropdown" id="vector-user-links-dropdown-checkbox" role="button" type="checkbox"/>
# <label aria-hidden="true" class="vector-dropdown-label cdx-button cdx-button--fake-button cdx-button--fake-button--enabled cdx-button--weight-quiet cdx-button--icon-only" for="vector-user-links-dropdown-checkbox" id="vector-user-links-dropdown-label"><span class="vector-icon mw-ui-icon-ellipsis mw-ui-icon-wikimedia-ellipsis"></span>
# <span class="vector-dropdown-label-text">Personal tools</span>
# </label>
# <div class="vector-dropdown-content">
# <div class="vector-menu mw-portlet mw-portlet-personal user-links-collapsible-item" id="p-personal" title="User menu">
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="user-links-collapsible-item mw-list-item" id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Chicken" title="You are encouraged to create an account and log in; however, it is not mandatory"><span class="vector-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span> <span>Create account</span></a></li><li class="user-links-collapsible-item mw-list-item" id="pt-login"><a accesskey="o" href="/w/index.php?title=Special:UserLogin&amp;returnto=Chicken" title="You're encouraged to log in; however, it's not mandatory. [o]"><span class="vector-icon mw-ui-icon-logIn mw-ui-icon-wikimedia-logIn"></span> <span>Log in</span></a></li>
# </ul>
# </div>
# </div>
# <div class="vector-menu mw-portlet mw-portlet-user-menu-anon-editor" id="p-user-menu-anon-editor">
# <div class="vector-menu-heading">
# 		Pages for logged out editors <a aria-label="Learn more about editing" href="/wiki/Help:Introduction"><span>learn more</span></a>
# </div>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list">
# <li class="mw-list-item" id="pt-anoncontribs"><a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]"><span>Contributions</span></a></li><li class="mw-list-item" id="pt-anontalk"><a accesskey="n" href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]"><span>Talk</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </header>
# </div>
# <div class="mw-page-container">
# <div class="mw-page-container-inner">
# <div class="vector-sitenotice-container">
# <div id="siteNotice"><!-- CentralNotice --></div>
# </div>
# <div class="vector-column-start">
# <div class="vector-main-menu-container">
# <div id="mw-navigation">
# <nav aria-label="Site" class="vector-main-menu-landmark" id="mw-panel" role="navigation">
# <div class="vector-pinned-container" id="vector-main-menu-pinned-container">
# </div>
# </nav>
# </div>
# </div>
# <div class="vector-sticky-pinned-container">
# <nav aria-label="Contents" class="mw-table-of-contents-container vector-toc-landmark" data-event-name="ui.sidebar-toc" id="mw-panel-toc" role="navigation">
# <div class="vector-pinned-container" id="vector-toc-pinned-container">
# <div class="vector-toc vector-pinnable-element" id="vector-toc">
# <div class="vector-pinnable-header vector-toc-pinnable-header vector-pinnable-header-pinned" data-feature-name="toc-pinned" data-pinnable-element-id="vector-toc">
# <h2 class="vector-pinnable-header-label">Contents</h2>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-pin-button" data-event-name="pinnable-header.vector-toc.pin">move to sidebar</button>
# <button class="vector-pinnable-header-toggle-button vector-pinnable-header-unpin-button" data-event-name="pinnable-header.vector-toc.unpin">hide</button>
# </div>
# <ul class="vector-toc-contents" id="mw-panel-toc-list">
# <li class="vector-toc-list-item vector-toc-level-1" id="toc-mw-content-text">
# <a class="vector-toc-link" href="#">
# <div class="vector-toc-text">(Top)</div>
# </a>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Nomenclature">
# <a class="vector-toc-link" href="#Nomenclature">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">1</span>Nomenclature</div>
# </a>
# <ul class="vector-toc-list" id="toc-Nomenclature-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Description">
# <a class="vector-toc-link" href="#Description">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">2</span>Description</div>
# </a>
# <ul class="vector-toc-list" id="toc-Description-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Reproduction_and_life-cycle">
# <a class="vector-toc-link" href="#Reproduction_and_life-cycle">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">3</span>Reproduction and life-cycle</div>
# </a>
# <ul class="vector-toc-list" id="toc-Reproduction_and_life-cycle-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Origin_and_dispersal">
# <a class="vector-toc-link" href="#Origin_and_dispersal">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4</span>Origin and dispersal</div>
# </a>
# <button aria-controls="toc-Origin_and_dispersal-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
# <span class="vector-icon vector-icon--x-small mw-ui-icon-wikimedia-expand"></span>
# <span>Toggle Origin and dispersal subsection</span>
# </button>
# <ul class="vector-toc-list" id="toc-Origin_and_dispersal-sublist">
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Origin">
# <a class="vector-toc-link" href="#Origin">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4.1</span>Origin</div>
# </a>
# <ul class="vector-toc-list" id="toc-Origin-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Domestication">
# <a class="vector-toc-link" href="#Domestication">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4.2</span>Domestication</div>
# </a>
# <ul class="vector-toc-list" id="toc-Domestication-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Dispersal">
# <a class="vector-toc-link" href="#Dispersal">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">4.3</span>Dispersal</div>
# </a>
# <ul class="vector-toc-list" id="toc-Dispersal-sublist">
# </ul>
# </li>
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Diseases">
# <a class="vector-toc-link" href="#Diseases">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">5</span>Diseases</div>
# </a>
# <ul class="vector-toc-list" id="toc-Diseases-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-1 vector-toc-list-item-expanded" id="toc-Use_by_humans">
# <a class="vector-toc-link" href="#Use_by_humans">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6</span>Use by humans</div>
# </a>
# <button aria-controls="toc-Use_by_humans-sublist" class="cdx-button cdx-button--weight-quiet cdx-button--icon-only vector-toc-toggle">
# <span class="vector-icon vector-icon--x-small mw-ui-icon-wikimedia-expand"></span>
# <span>Toggle Use by humans subsection</span>
# </button>
# <ul class="vector-toc-list" id="toc-Use_by_humans-sublist">
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-Farming">
# <a class="vector-toc-link" href="#Farming">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6.1</span>Farming</div>
# </a>
# <ul class="vector-toc-list" id="toc-Farming-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-As_pets">
# <a class="vector-toc-link" href="#As_pets">
# <div class="vector-toc-text">
# <span class="vector-toc-numb">6.2</span>As pets</div>
# </a>
# <ul class="vector-toc-list" id="toc-As_pets-sublist">
# </ul>
# </li>
# <li class="vector-toc-list-item vector-toc-level-2" id="toc-
hreflang="en"><span>Wikimedia Commons</span></a></li><li class="wb-otherproject-link wb-otherproject-wikibooks mw-list-item"><a href="https://en.wikibooks.org/wiki/Cookbook:Chicken" hreflang="en"><span>Wikibooks</span></a></li><li class="wb-otherproject-link wb-otherproject-wikiquote mw-list-item"><a href="https://en.wikiquote.org/wiki/Chickens" hreflang="en"><span>Wikiquote</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </div>
# </div>
# </div>
# <div class="vector-column-end">
# <div class="vector-sticky-pinned-container">
# <nav aria-label="Page tools" class="vector-page-tools-landmark">
# <div class="vector-pinned-container" id="vector-page-tools-pinned-container">
# </div>
# </nav>
# <nav aria-label="Appearance" class="vector-client-prefs-landmark">
# </nav>
# </div>
# </div>
# <div aria-labelledby="firstHeading" class="vector-body" data-mw-ve-target-container="" id="bodyContent">
# <div class="vector-body-before-content">
# <div class="mw-indicators">
# <div class="mw-indicator" id="mw-indicator-good-star"><div class="mw-parser-output"><span typeof="mw:File"><a href="/wiki/Wikipedia:Good_articles*" title="This is a good article. Click here for more information."><img alt="This is a good article. Click here for more information." class="mw-file-element" data-file-height="185" data-file-width="180" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/29px-Symbol_support_vote.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/39px-Symbol_support_vote.svg.png 2x" width="19"/></a></span></div></div>
# <div class="mw-indicator" id="mw-indicator-pp-default"><div class="mw-parser-output"><span typeof="mw:File"><a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected."><img alt="Page semi-protected" class="mw-file-element" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/></a></span></div></div>
# </div>
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# </div>
# <div id="contentSub"><div id="mw-content-subtitle"></div></div>
# <div class="mw-body-content" id="mw-content-text"><div class="mw-content-ltr mw-parser-output" dir="ltr" lang="en"><p class="mw-empty-elt">
# </p>
# <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">Domesticated species of bird</div>
# <style data-mw-deduplicate="TemplateStyles:r1033289096">.mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}</style><div class="hatnote navigation-not-searchable" role="note">For the culinary use of chickens, see <a href="/wiki/Chicken_as_food" title="Chicken as food">Chicken as food</a>. For other uses, see <a class="mw-disambig" href="/wiki/Chicken_(disambiguation)" title="Chicken (disambiguation)">Chicken (disambiguation)</a> and <a class="mw-disambig" href="/wiki/Chooks_(disambiguation)" title="Chooks (disambiguation)">Chooks (disambiguation)</a>.</div>
# <link href="mw-data:TemplateStyles:r1033289096" rel="mw-deduplicated-inline-style"/><div class="hatnote navigation-not-searchable" role="note">"Rooster" and "Roosters" redirect here. For other uses, see <a class="mw-disambig" href="/wiki/Rooster_(disambiguation)" title="Rooster (disambiguation)">Rooster (disambiguation)</a>.</div>
# <link href="mw-data:TemplateStyles:r1033289096" rel="mw-deduplicated-inline-style"/><div class="hatnote navigation-not-searchable" role="note">"Cockerel" redirects here. For the Fabergé egg, see <a href="/wiki/Cockerel_(Faberg%C3%A9_egg)" title="Cockerel (Fabergé egg)">Cockerel (Fabergé egg)</a>.</div>
# <p>
# <span class="anchor" id="Cockerel"></span><span class="anchor" id="Hen"></span><span class="anchor" id="Pullet"></span><span class="anchor" id="Rooster"></span>
# </p>
# <table class="infobox biota" style="text-align: left; width: 200px; font-size: 100%">
# <tbody><tr>
# <th colspan="2" style="text-align: center; background-color: rgb(235,235,210)">Chicken
# </th></tr>
# <tr>
# <td colspan="2" style="text-align: center"><span class="mw-default-size" typeof="mw:File/Frameless"><a class="mw-file-description" href="/wiki/File:Male_and_female_chicken_sitting_together.jpg"><img class="mw-file-element" data-file-height="1280" data-file-width="959" decoding="async" height="294" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/84/Male_and_female_chicken_sitting_together.jpg/220px-Male_and_female_chicken_sitting_together.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/84/Male_and_female_chicken_sitting_together.jpg/330px-Male_and_female_chicken_sitting_together.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/84/Male_and_female_chicken_sitting_together.jpg/440px-Male_and_female_chicken_sitting_together.jpg 2x" width="220"/></a></span>
# </td></tr>
# <tr>
# <td colspan="2" style="text-align: center; font-size: 88%">Male (left) and female chickens
# </td></tr>
# <tr style="text-align: center; background-color: rgb(235,235,210)">
# <th colspan="2"><div style="text-align: center"><a href="/wiki/Conservation_status" title="Conservation status">Conservation status</a></div>
# </th></tr>
# <tr>
# <td colspan="2"><div style="text-align: center">Domesticated<small></small></div>
# </td></tr>
# <tr>
# ...
# <li><span style="white-space:nowrap;"><a href="/wiki/Global_Biodiversity_Information_Facility" title="Global Biodiversity Information Facility">GBIF</a>: <span class="uid"><a class="external text" href="https://www.gbif.org/species/9457155" rel="nofollow">9457155</a></span></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/INaturalist" title="INaturalist">iNaturalist</a>: <span class="uid"><a class="external text" href="https://inaturalist.org/taxa/505478" rel="nofollow">505478</a></span></span></li>
# <li><span style="white-space:nowrap;"><a href="/wiki/National_Biodiversity_Network" title="National Biodiversity Network">NBN</a>: <span class="uid"><a class="external text" href="https://data.nbn.org.uk/Taxa/NHMSYS0020975169" rel="nofollow">NHMSYS0020975169</a></span></span></li>
# <li><span style="white-space:nowrap;">NZOR: <span class="uid"><a class="external text" href="https://www.nzor.org.nz/names/00228927-f07c-4b05-8012-b9e8fb65eb3c" rel="nofollow">00228927-f07c-4b05-8012-b9e8fb65eb3c</a></span></span></li>
# <li><span style="white-space:nowrap;"><a class="extiw" href="https://de.wikipedia.org/wiki/Tierstimmenarchiv" title="de:Tierstimmenarchiv">TSA</a>: <span class="uid"><a class="external text" href="http://www.tierstimmen.org/en/database?field_spec_species_target_id_selective=7267" rel="nofollow">7267</a></span></span></li></ul>
# </div></td></tr></tbody></table></div>
# <div class="navbox-styles"><link href="mw-data:TemplateStyles:r1129693374" rel="mw-deduplicated-inline-style"/><link href="mw-data:TemplateStyles:r1061467846" rel="mw-deduplicated-inline-style"
a></li><li><a href="/wiki/Category:Articles_with_short_description" title="Category:Articles with short description">Articles with short description</a></li><li><a href="/wiki/Category:Short_description_is_different_from_Wikidata" title="Category:Short description is different from Wikidata">Short description is different from Wikidata</a></li><li><a href="/wiki/Category:Wikipedia_indefinitely_move-protected_pages" title="Category:Wikipedia indefinitely move-protected pages">Wikipedia indefinitely move-protected pages</a></li><li><a href="/wiki/Category:Wikipedia_indefinitely_semi-protected_pages" title="Category:Wikipedia indefinitely semi-protected pages">Wikipedia indefinitely semi-protected pages</a></li><li><a href="/wiki/Category:Use_mdy_dates_from_September_2023" title="Category:Use mdy dates from September 2023">Use mdy dates from September 2023</a></li><li><a href="/wiki/Category:Articles_with_%27species%27_microformats" title="Category:Articles with 'species' microformats">Articles with 'species' microformats</a></li><li><a href="/wiki/Category:Articles_containing_potentially_dated_statements_from_2018" title="Category:Articles containing potentially dated statements from 2018">Articles containing potentially dated statements from 2018</a></li><li><a href="/wiki/Category:All_articles_containing_potentially_dated_statements" title="Category:All articles containing potentially dated statements">All articles containing potentially dated statements</a></li><li><a href="/wiki/Category:Commons_category_link_is_on_Wikidata" title="Category:Commons category link is on Wikidata">Commons category link is on Wikidata</a></li><li><a href="/wiki/Category:Articles_with_BNF_identifiers" title ...
# </div>
# </main>
# </div>
# <div class="mw-footer-container">
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> This page was last edited on 22 February 2024, at 15:49<span class="anonymous-show"> (UTC)</span>.</li>
# <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license">Creative Commons Attribution-ShareAlike License 4.0</a><a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License" rel="license" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy">Privacy policy</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:About">About Wikipedia</a></li>
# <li id="footer-places-disclaimers"><a href="/wiki/Wikipedia:General_disclaimer">Disclaimers</a></li>
# <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# <li id="footer-places-wm-codeofconduct"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct">Code of Conduct</a></li>
# <li id="footer-places-developers"><a href="https://developer.wikimedia.org">Developers</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement">Cookie statement</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Chicken&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# </footer>
# </div>
# </div>
# </div>
# <div class="vector-settings" id="p-dock-bottom">
# <ul>
# <li>
# <button class="cdx-button cdx-button--icon-only vector-limited-width-toggle" id=""><span class="vector-icon mw-ui-icon-fullScreen mw-ui-icon-wikimedia-fullScreen"></span>
# <span>Toggle limited content width</span>
# </button>
# </li>
# </ul>
# </div>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgHostname":"mw1365","wgBackendResponseTime":179,"wgPageParseReport":{"limitreport":{"cputime":"1.370","walltime":"1.829","ppvisitednodes":{"value":14878,"limit":1000000},"postexpandincludesize":{"value":282843,"limit":2097152},"templateargumentsize":{"value":9563,"limit":2097152},"expansiondepth":{"value":20,"limit":100},"expensivefunctioncount":{"value":31,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":359370,"limit":5000000},"entityaccesscount":{"value":7,"limit":400},"timingprofile":["100.00% 1642.286      1 -total"," 40.55%  666.001      2 Template:Reflist"," 16.10%  264.375      1 Template:Speciesbox"," 15.77%  259.063      1 Template:Taxobox/core"," 13.90%  228.325     39 Template:Cite_journal"," 10.49%  172.334     34 Template:Cite_web","  5.77%   94.789      1 Template:Taxonbar","  5.48%   90.031      2 Template:Navbox","  5.39%   88.453      1 Template:Chicken","  4.94%   81.173      1 Template:Short_description"]},"scribunto":{"limitreport-timeusage":{"value":"0.934","limit":"10.000"},"limitreport-memusage":{"value":11341270,"limit":52428800}},"cachereport":{"origin":"mw-web.eqiad.main-5c64554744-hwlx7","timestamp":"20240303070515","ttl":2592000,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Chicken","url":"https:\/\/en.wikipedia.org\/wiki\/Chicken","sameAs":"http:\/\/www.wikidata.org\/entity\/Q780","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q780","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2002-02-03T18:26:01Z","dateModified":"2024-02-22T15:49:27Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/8\/84\/Male_and_female_chicken_sitting_together.jpg","headline":"domesticated bird kept by humans primarily as a food source"}</script>
# </body>
# </html>

# %% [markdown]
# That seemed to work fine. Notice I had to run BeautifulSoup on `page.content`, because `page` itself is just the HTTP response:

# %%
print(type(page))
# Out:
# <class 'requests.models.Response'>

# %% [markdown]
# Here we have a status code of `200` meaning the request is successful.

# %%
print(page.status_code)
# Out:
# 200

# %%
for method in dir(page):
    print(method)
# Out:
# __attrs__
# __bool__
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __enter__
# __eq__
# __exit__
# __format__
# __ge__
# __getattribute__
# __getstate__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __iter__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __nonzero__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __setstate__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# _content
# _content_consumed
# _next
# apparent_encoding
# close
# connection
# content
# cookies
# elapsed
# encoding
# headers
# history
# is_permanent_redirect
# is_redirect
# iter_content
# iter_lines
# json
# links
# next
# ok
# raise_for_status
# raw
# reason
# request
# status_code
# text
# url

# %% [markdown]
# Let's do some BeautifulSoup magic and grab all the links from the page. A HTML link is always in a `<a>` tag, and specifically is under the `href` attribute of the `<a>` tag.
#
# I am putting this in a `try` `except` block here as_not every_ `<a>` tag will necessarily have an `href` attribute. Try running:
#
# ```python
# links = []
#
# for a in soup.find_all("a"):
#     links.append(a["href"])
# ```
#
# You'll get an error and the whole loop is ruined. Getting used to when and where to use `try` `except` isn't always obvious, but it is a way of _catching_ an error, handling it in some way, and then _continuing_ as opposed to simply crashing :(

# %%
links = []

for a in soup.find_all("a"):
    try:
        links.append(a["href"])
    except:
        pass
    
for link in links:
    print(link)
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /w/index.php?title=Special:CreateAccount&returnto=Chicken
# /w/index.php?title=Special:UserLogin&returnto=Chicken
# /w/index.php?title=Special:CreateAccount&returnto=Chicken
# /w/index.php?title=Special:UserLogin&returnto=Chicken
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Nomenclature
# #Description
# #Reproduction_and_life-cycle
# #Origin_and_dispersal
# #Origin
# #Domestication
# #Dispersal
# #Diseases
# #Use_by_humans
# #Farming
# #As_pets
# #Cockfighting
# #In_science
# #In_culture,_folklore,_and_religion
# #Notes
# #References
# #External_links
# https://kbd.wikipedia.org/wiki/%D0%A3%D0%BD%D1%8D_%D0%B4%D0%B6%D1%8D%D0%B4%D1%85%D1%8D%D1%80
# https://af.wikipedia.org/wiki/Hoender
# https://als.wikipedia.org/wiki/Haushuhn
# https://am.wikipedia.org/wiki/%E1%8B%B6%E1%88%AE
# https://ang.wikipedia.org/wiki/Henn
# https://ar.wikipedia.org/wiki/%D8%AF%D8%AC%D8%A7%D8%AC
# https://an.wikipedia.org/wiki/Gallus_gallus_domesticus
# https://roa-rup.wikipedia.org/wiki/G%C3%A2%C4%BEin%C3%A2
# https://frp.wikipedia.org/wiki/Gallus_gallus_domesticus
# https://as.wikipedia.org/wiki/%E0%A6%95%E0%A7%81%E0%A6%95%E0%A7%81%E0%A7%B0%E0%A6%BE
# https://ast.wikipedia.org/wiki/Gallus_gallus_domesticus
# https://atj.wikipedia.org/wiki/Pakahakwan
# https://gn.wikipedia.org/wiki/Ryguasu
# https://av.wikipedia.org/wiki/%D0%93%D3%80%D0%B0%D0%BD%D0%BA%D3%80%D1%83
# https://ay.wikipedia.org/wiki/Chiwchi
# https://az.wikipedia.org/wiki/Toyuq
# https://azb.wikipedia.org/wiki/%D8%AA%D9%88%DB%8C%D9%88%D9%82
# https://ban.wikipedia.org/wiki/Siap
# https://bn.wikipedia.org/wiki/%E0%A6%AE%E0%A7%81%E0%A6%B0%E0%A6%97%E0%A6%BF
# https://bjn.wikipedia.org/wiki/Hayam
# https://zh-min-nan.wikipedia.org/wiki/Ke
# https://ba.wikipedia.org/wiki/%D0%A2%D0%B0%D1%83%D1%8B%D2%A1
# https://be.wikipedia.org/wiki/%D0%9A%D1%83%D1%80%D1%8B%D1%86%D0%B0
# https://be-tarask.wikipedia.org/wiki/%D0%9A%D1%83%D1%80%D1%8B%D1%86%D0%B0
# https://bh.wikipedia.org/wiki/%E0%A4%A6%E0%A5%87%E0%A4%B8%E0%A5%80_%E0%A4%AE%E0%A5%81%E0%A4%B0%E0%A5%8D%E0%A4%97%E0%A4%BE
# https://bcl.wikipedia.org/wiki/Manok
# https://bg.wikipedia.org/wiki/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B0_%D0%BA%D0%BE%D0%BA%D0%BE%D1%88%D0%BA%D0%B0
wikipedia.org/wiki/%D0%9A%D0%BE%D0%BA%D0%BE%D1%88%D0%BA%D0%B0
# https://sh.wikipedia.org/wiki/Doma%C4%87a_koko%C5%A1
# https://su.wikipedia.org/wiki/Hayam
# https://fi.wikipedia.org/wiki/Kana
# https://sv.wikipedia.org/wiki/Tamh%C3%B6na
# https://tl.wikipedia.org/wiki/Manok
# https://ta.wikipedia.org/wiki/%E0%AE%95%E0%AF%8B%E0%AE%B4%E0%AE%BF
# https://kab.wikipedia.org/wiki/Yuza%E1%B9%AD
# https://roa-tara.wikipedia.org/wiki/Jadde
# https://tt.wikipedia.org/wiki/%D0%99%D0%BE%D1%80%D1%82_%D1%82%D0%B0%D0%B2%D1%8B%D0%B3%D1%8B
# https://tay.wikipedia.org/wiki/welung
# https://te.wikipedia.org/wiki/%E0%B0%95%E0%B1%8B%E0%B0%A1%E0%B0%BF
# https://th.wikipedia.org/wiki/%E0%B9%84%E0%B8%81%E0%B9%88
# https://din.wikipedia.org/wiki/Aj%C3%AFth
# https://tg.wikipedia.org/wiki/%D0%9C%D1%83%D1%80%D2%93
# https://chy.wikipedia.org/wiki/Kok%C3%AAh%C3%A9axa
# https://tcy.wikipedia.org/wiki/%E0%B2%95%E0%B3%8B%E0%B2%B0%E0%B2%BF
# https://tr.wikipedia.org/wiki/Tavuk
# https://tk.wikipedia.org/wiki/Towuk
# https://kcg.wikipedia.org/wiki/Nywan
# https://udm.wikipedia.org/wiki/%D0%9A%D1%83%D1%80%D0%B5%D0%B3
# https://uk.wikipedia.org/wiki/%D0%9A%D1%83%D1%80%D0%BA%D0%B0
# https://ur.wikipedia.org/wiki/%D9%85%D8%B1%D8%BA%DB%8C
# https://za.wikipedia.org/wiki/Gaeq
# https://vep.wikipedia.org/wiki/Kana
# https://vi.wikipedia.org/wiki/G%C3%A0
# https://vo.wikipedia.org/wiki/Jigok
# https://fiu-vro.wikipedia.org/wiki/Kana
# https://wa.wikipedia.org/wiki/Poye
# https://zh-classical.wikipedia.org/wiki/%E9%9B%9E
# https://vls.wikipedia.org/wiki/Henne
# https://war.wikipedia.org/wiki/Man%C3%B3k
# https://wo.wikipedia.org/wiki/Ganaar
# https://wuu.wikipedia.org/wiki/%E9%B8%A1
# https://yi.wikipedia.org/wiki/%D7%94%D7%90%D7%9F
# https://zh-yue.wikipedia.org/wiki/%E9%9B%9E
# https://diq.wikipedia.org/wiki/Kerge_(heywan)
# https://bat-smg.wikipedia.org/wiki/V%C4%97%C5%A1ta
# https://zh.wikipedia.org/wiki/%E9%B8%A1
# https://tly.wikipedia.org/wiki/Kag
# https://www.wikidata.org/wiki/Special:EntityPage/Q780#sitelinks-wikipedia
# /wiki/Chicken
# /wiki/Talk:Chicken
# /wiki/Chicken
# /w/index.php?title=Chicken&action=edit
# /w/index.php?title=Chicken&action=history
# /wiki/Chicken
# /w/index.php?title=Chicken&action=edit
# /w/index.php?title=Chicken&action=history
# /wiki/Special:WhatLinksHere/Chicken
# /wiki/Special:RecentChangesLinked/Chicken
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Chicken&oldid=1209576901
# /w/index.php?title=Chicken&action=info
# /w/index.php?title=Special:CiteThisPage&page=Chicken&id=1209576901&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FChicken
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FChicken
# https://www.wikidata.org/wiki/Special:EntityPage/Q780
# /w/index.php?title=Special:DownloadAsPdf&page=Chicken&action=show-download-screen
# /w/index.php?title=Chicken&printable=yes
# https://commons.wikimedia.org/wiki/Chickens
# https://en.wikibooks.org/wiki/Cookbook:Chicken
# https://en.wikiquote.org/wiki/Chickens
# /wiki/Wikipedia:Good_articles*
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Chicken_as_food
# /wiki/Chicken_(disambiguation)
# /wiki/Chooks_(disambiguation)
# /wiki/Rooster_(disambiguation)
# /wiki/Cockerel_(Faberg%C3%A9_egg)
# /wiki/File:Male_and_female_chicken_sitting_together.jpg
# /wiki/Conservation_status
# /wiki/Taxonomy_(biology)
# /wiki/Template:Taxonomy/Gallus
# /wiki/Eukaryote
# /wiki/Animal
# /wiki/Chordate
# /wiki/Bird
# /wiki/Galliformes
# /wiki/Phasianidae
# /wiki/Junglefowl
# /wiki/Binomial_nomenclature
# /wiki/Carl_Linnaeus
# /wiki/10th_edition_of_Systema_Naturae
# /wiki/File:GLW_2_global_distributions_of_c)_chickens.tif
# /wiki/Synonym_(taxonomy)
# /wiki/L.
# /wiki/Domestication
# /wiki/Red_junglefowl
# /wiki/Southeast_Asia
# /wiki/Chicken_as_food
# /wiki/Egg_as_food
# /wiki/Pet
# /wiki/Cockfight
# https://en.wikipedia.org/w/index.php?title=Chicken&action=edit
# /wiki/Cultural_references_to_chickens
# #cite_note-1
# #cite_note-2
# /wiki/Capon
# /wiki/Neutered
# #cite_note-3
# /wiki/Chick_(young_bird)
# #cite_note-4
# /wiki/Help:IPA/English
# #cite_note-5
# #cite_note-6
# #cite_note-7
# #cite_note-8
# #cite_note-9
# #cite_note-10
# #cite_note-11
# #cite_note-12
# #cite_note-Rawson-13
# #cite_note-Online_Etymology_Dictionary-14
# #cite_note-berhardt-15
# /wiki/Hen_and_Chicken_Islands
# #cite_note-16
# #cite_note-17
# /wiki/File:Rooster_portrait2.jpg
# /wiki/Comb_(anatomy)
# /wiki/File:Hen_Comb_(cropped).jpg
# /wiki/Bird
# /wiki/Diurnality
# #cite_note-Smithsonian-18
# /wiki/Junglefowl
# /wiki/Bird_flight
# /wiki/Flight_muscle
# #cite_note-19
# #cite_note-Smithsonian-18
# /wiki/Wattle_(anatomy)
# /wiki/Sexual_dimorphism
# /wiki/Mutation
# #cite_note-plosg-20
# /wiki/Omnivore
# #cite_note-21
# /wiki/Lizard
# #cite_note-22
# /wiki/Mouse
# #cite_note-23
# /wiki/Breed
# #cite_note-24
# #cite_note-25
# /wiki/Gregarious
# /wiki/Herd
# /wiki/Egg_incubation
# /wiki/Dominance_hierarchy
# /wiki/Thorleif_Schjelderup-Ebbe
# #cite_note-26
# #cite_note-27
# #cite_note-28
# #cite_note-29
# #cite_note-30
# /wiki/Warning_call
# /wiki/Predation
# #cite_note-31
# #cite_note-grandin69-32
# #cite_note-grandin69-32
# #cite_note-33
# /wiki/Cloaca
# #cite_note-Briskie1997-34
# /wiki/Neuroendocrine_cell
# /wiki/Gonadotropin-Releasing_Hormone-I_neuron
# /wiki/Hypothalamus
# /wiki/Estrogen
# /wiki/Progesterone
# /wiki/Gonadotropin
# /wiki/Luteinizing_hormone
# /wiki/Follicle-stimulating_hormone
# #cite_note-Bain-et-al-2016-35
# /wiki/File:Newly-hatched_chickens.jpg
# #cite_note-36
# /wiki/Clutch_(eggs)
# /wiki/Broodiness
# #cite_note-Puff-up-Feathers-37
# /wiki/Tibet
# /wiki/Hemoglobin
# #cite_note-38
# /wiki/Egg_tooth
# #cite_note-grandin69-32
# /wiki/Yolk_sac
# #cite_note-39
# /wiki/Imprinting_(psychology)
# #cite_note-Edgar_Held_Jones_Troisi_2016_p._2-40
# /wiki/File:Red_Junglefowl.jpg
# /wiki/Red_junglefowl
# /wiki/Partridge
# /wiki/Galliformes
# /wiki/Order_(biology)
# /wiki/Cretaceous%E2%80%93Paleogene_extinction_event
# /wiki/Dinosaur
# #cite_note-41
# /wiki/Red_junglefowl
# #cite_note-nature-42
# #cite_note-nature-42
# /wiki/Grey_junglefowl
# /wiki/Sri_Lankan_junglefowl
# /wiki/Green_junglefowl
# #cite_note-Lawal-43
# #cite_note-44
# #cite_note-Lawal-43
# /wiki/Domestication
# /wiki/File:Chicken_domestication_and_dispersal.svg
# #cite_note-Lawal-43
# /wiki/Thailand
# #cite_note-oneMatriarch-45
# /wiki/Bamboo#Mass_flowering
# /wiki/Bamboo#Mass_flowering
# #cite_note-46
# #cite_note-47
# #cite_note-Lawal-43
# #cite_note-Lawal-43
# #cite_note-West_Zhou_1988-48
# #cite_note-49
# #cite_note-50
# #cite_note-51
# #cite_note-52
# /wiki/File:Map_showing_prehistoric_diffusion_of_domestic_chickens_(Gallus_gallus)_into_the_Pacific_via_the_Austronesian_migrations_(Thomson,_Lebrasseur,_%26_Austin,_2014).png
# /wiki/Oceania
# /wiki/Philippines
# /wiki/Neolithic
# /wiki/Austronesian_expansion
# /wiki/Before_present
# #cite_note-Thomson-53
# /wiki/Proto-Austronesian_language
# /wiki/Domesticated_plants_and_animals_of_Austronesia
# /wiki/Austronesian_peoples
# /wiki/Island_Southeast_Asia
# /wiki/Micronesia
# /wiki/Island_Melanesia
# /wiki/Polynesia
# /wiki/Madagascar
# /wiki/Indigenous_Taiwanese
# #cite_note-Thomson-53
# #cite_note-Piper-54
# #cite_note-55
# #cite_note-56
# /wiki/Pre-Columbian
# /wiki/South_America
# /wiki/Polynesians
# #cite_note-Neumann-57
# /wiki/Syria
# /wiki/Cockfighting
# #cite_note-CHOF-58
# /wiki/Hellenistic_period
# /wiki/Levant
# #cite_note-pmid26195775-59
# /wiki/Corinth,_Greece
# /wiki/Pottery
# #cite_note-60
# #cite_note-61
# /wiki/Roman_Empire
# /wiki/Middle_Ages
# #cite_note-CHOF-58
# /wiki/DNA_sequencing
# /wiki/High_Middle_Ages
# #cite_note-brown-62
# /wiki/Nile_River
# /wiki/Sahara_Desert
# #cite_note-CHOF-58
# /wiki/Extinction
# #cite_note-CHOF-58
# /wiki/Arauco_Peninsula
# /wiki/Zona_Sur
# #cite_note-63
# #cite_note-64
# #cite_note-65
# #cite_note-ThomsonLebrasseur2014-66
# /wiki/Poultry_disease
# /wiki/File:Pesse_oujheas_H9N2_tanfla.JPG
# /wiki/Avian_influenza
# /wiki/Parasitism
# /wiki/Mite
# /wiki/Poultry_disease
# /wiki/Pathogen
# /wiki/Bacteria
# /wiki/Virus
# /wiki/Dermanyssus_gallinae
# /wiki/Salmonellosis
# /wiki/Borrelia_anserina
# #cite_note-Schiavone_Pugliese_2022-67
# /wiki/Avian_influenza
# #cite_note-68
# /wiki/Poultry_farming
# https://en.wikipedia.org/w/index.php?title=Chicken&action=edit
# #cite_note-69
# #cite_note-70
# #cite_note-71
# #cite_note-72
# /wiki/Intensive_animal_farming
# /wiki/Worldwatch_Institute
# #cite_note-73
# /wiki/Free-range
# /wiki/Ethical_consumerism
# /wiki/Intensive_farming
# #cite_note-74
# #cite_note-75
# /wiki/Broiler
# #cite_note-76
# /wiki/Free_range
# /wiki/Organic_(food)
# #cite_note-77
# /wiki/File:Florida_chicken_house.jpg
# #cite_note-78
# #cite_note-79
# /wiki/Battery_cage
# #cite_note-Browne-80
# #cite_note-Browne-80
# /wiki/Forced_molting
# #cite_note-Patwardhan_and_King,_(2011)-81
# #cite_note-Webster,_(2003)-82
# #cite_note-Molino_et_al.,_(2009)-83
# #cite_note-Yousaf_and_Chaudhry,_(2008)-84
# #cite_note-85
# #cite_note-86
# #cite_note-87
# #cite_note-88
# #cite_note-89
# #cite_note-UPC_good_homes-90
# /wiki/Silkie
# /wiki/Bantam_(poultry)
# #cite_note-91
# /wiki/Cockfight
# /wiki/File:COCK_FIGHT.JPG
# /wiki/Cockfight
# /wiki/Tamil_Nadu
# /wiki/Cockfight
# /wiki/Cruelty_to_animals
# #cite_note-92
# /wiki/Indus_Valley_civilisation
# #cite_note-Crawford_1990-93
# #cite_note-Lawler_Adler_2012-94
# /wiki/Model_organism
# /wiki/Limb_development
# /wiki/Apical_ectodermal_ridge
# /wiki/Zone_of_polarizing_activity
# #cite_note-95
# /wiki/Genome
# #cite_note-96
# /wiki/Human_genome
# #cite_note-97
# /wiki/Pseudogene
# #cite_note-98
# /wiki/Recessive_gene
# #cite_note-99
# /wiki/Cultural_references_to_chickens
# /wiki/Folklore
# /wiki/Religion
# /wiki/Literature
# #cite_note-smithsonianmag.com-100
# /wiki/Divination
# /wiki/Cockfight
# #cite_note-101
# /wiki/Gabriel_Garc%C3%ADa_M%C3%A1rquez
# /wiki/One_Hundred_Years_Of_Solitude
# #cite_note-102
# /wiki/Chicken_joke
# /wiki/The_Knickerbocker
# #cite_note-103
# /wiki/Adriaen_van_Utrecht
# /wiki/Walter_Osborne
# #cite_note-104
# /wiki/Nursery_rhyme
# /wiki/Cock_a_doodle_doo
# /wiki/Mother_Goose%27s_Melody
# #cite_note-105
# /wiki/Adventure_film
# /wiki/Comedy_film
# /wiki/Chicken_Run
# /wiki/Peter_Lord
# /wiki/Nick_Park
# /wiki/Anthropomorphism
# #cite_note-106
# #cite_note-107
# #cite_note-108
# /wiki/File:Terracotta_askos_(flask)_in_the_form_of_a_rooster_MET_DP252108_(cropped).jpg
# /wiki/Etruscan_civilization
# /wiki/File:Rooster_and_hen,_Dong_Ho_picture,_paper_-_Vietnam_National_Museum_of_Fine_Arts_-_Hanoi,_Vietnam_-_DSC05287.JPG
# /wiki/%C4%90%C3%B4ng_H%E1%BB%93_painting
# /wiki/File:Feeding_the_chickens,_by_Walter_Frederick_Osborne.jpg
# /wiki/Walter_Osborne
# /wiki/Doi_(identifier)
# https://doi.org/10.1016%2F0168-1591%2893%2990011-d
# #cite_ref-Puff-up-Feathers_37-0
# https://chickenandchicksinfo.com/why-do-chickens-puff-up-their-feathers/
# https://web.archive.org/web/20210618091939/https://chickenandchicksinfo.com/why-do-chickens-puff-up-their-feathers/
# #cite_ref-38
# https://doi.org/10.3382%2Fps.2008-00122
# /wiki/Doi_(identifier)
# https://doi.org/10.3382%2Fps.2008-00122
# /wiki/ISSN_(identifier)
# https://www.worldcat.org/issn/0032-5791
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/18809874
# #cite_ref-39
# https://doi.org/10.3382%2Fps.0640789
# /wiki/Doi_(identifier)
# https://doi.org/10.3382%2Fps.0640789
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/4001066
# #cite_ref-Edgar_Held_Jones_Troisi_2016_p._2_40-0
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4730119
# /wiki/Doi_(identifier)
# https://doi.org/10.3390%2Fani6010002
# /wiki/ISSN_(identifier)
# https://www.worldcat.org/issn/2076-2615
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4730119
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/26742081
# #cite_ref-41
# /wiki/Elizabeth_Pennisi
# /wiki/Doi_(identifier)
# https://doi.org/10.1126%2Fscience.aau2802
# #cite_ref-nature_42-0
# #cite_ref-nature_42-1
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2263125
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2004Natur.432..717B
# /wiki/Doi_(identifier)
# https://doi.org/10.1038%2Fnature03156
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2263125
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/15592405
# #cite_ref-Lawal_43-0
# #cite_ref-Lawal_43-1
# #cite_ref-Lawal_43-2
# #cite_ref-Lawal_43-3
# #cite_ref-Lawal_43-4
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7014787
# /wiki/Doi_(identifier)
# https://doi.org/10.1186%2Fs12915-020-0738-1
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7014787
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/32050971
# #cite_ref-44
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2265484
# /wiki/Doi_(identifier)
# https://doi.org/10.1371%2Fjournal.pgen.1000010
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2265484
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/18454198
# #cite_ref-oneMatriarch_45-0
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/1994PNAS...9112505F
# /wiki/Doi_(identifier)
# https://doi.org/10.1073%2Fpnas.91.26.12505
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC45467
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/7809067
# #cite_ref-46
# https://www.pbs.org/wgbh/nova/nature/rat-attack.html
# https://web.archive.org/web/20170823151419/http://www.pbs.org/wgbh/nova/nature/rat-attack.html
# #cite_ref-47
# https://www.pbs.org/wgbh/nova/nature/plant-vs-predator.html
# https://web.archive.org/web/20170821123509/http://www.pbs.org/wgbh/nova/nature/plant-vs-predator.html
# #cite_ref-West_Zhou_1988_48-0
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/1988JArSc..15..515W
# /wiki/Doi_(identifier)
# https://doi.org/10.1016%2F0305-4403%2888%2990080-5
# #cite_ref-49
# /wiki/Doi_(identifier)
# https://doi.org/10.1017%2FS004393390700147X
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:86734013
# #cite_ref-50
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7395088
# /wiki/Doi_(identifier)
# https://doi.org/10.1038%2Fs41422-020-0349-y
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7395088
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/32581344
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:220050312
# #cite_ref-51
# /wiki/Doi_(identifier)
# https://doi.org/10.1016%2Fj.ympev.2005.09.014
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/16275023
# #cite_ref-52
# /wiki/Doi_(identifier)
# https://doi.org/10.1016%2Fj.tig.2006.01.007
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/16458995
# #cite_ref-Thomson_53-0
# #cite_ref-Thomson_53-1
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3977275
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2014PNAS..111.4826T
# /wiki/Doi_(identifier)
# https://doi.org/10.1073%2Fpnas.1320412111
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3977275
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/24639505
# #cite_ref-Piper_54-0
# http://press-files.anu.edu.au/downloads/press/n2320/html/ch15.xhtml
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9781760460945
# https://web.archive.org/web/20221128075413/https://press-files.anu.edu.au/downloads/press/n2320/html/ch15.xhtml
# #cite_ref-55
# https://books.google.com/books?id=FJ9ULYwX3zgC&pg=PA56
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:4418786
# #cite_ref-64
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1965514
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2007PNAS..10410335S
# /wiki/Doi_(identifier)
# https://doi.org/10.1073%2Fpnas.0703993104
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1965514
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/17556540
# #cite_ref-65
# /wiki/Atholl_Anderson
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2492461
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2008PNAS..10510308G
# /wiki/Doi_(identifier)
# https://doi.org/10.1073%2Fpnas.0801991105
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2492461
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/18663216
# #cite_ref-ThomsonLebrasseur2014_66-0
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3977275
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2014PNAS..111.4826T
# /wiki/Doi_(identifier)
# https://doi.org/10.1073%2Fpnas.1320412111
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3977275
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/24639505
# #cite_ref-Schiavone_Pugliese_2022_67-0
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8772161
# /wiki/Doi_(identifier)
# https://doi.org/10.1186%2Fs13071-021-05142-1
# /wiki/ISSN_(identifier)
# https://www.worldcat.org/issn/1756-3305
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8772161
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/35057849
# #cite_ref-68
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7129915
# /wiki/Doi_(identifier)
# https://doi.org/10.1016%2Fj.cyto.2019.154961
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7129915
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/31901597
# #cite_ref-69
# https://www.statista.com/statistics/263962/number-of-chickens-worldwide-since-1990/
# https://web.archive.org/web/20201127124744/https://www.statista.com/statistics/263962/number-of-chickens-worldwide-since-1990/
# #cite_ref-70
# https://www.ciwf.org.uk/farm-animals/chickens/
# https://web.archive.org/web/20170426063521/https://www.ciwf.org.uk/farm-animals/chickens/
# #cite_ref-71
# https://usda.library.cornell.edu/concern/publications/pg15bd88s
# https://web.archive.org/web/20170426063701/http://usda.mannlib.cornell.edu/MannUsda/viewDocumentInfo.do?documentID=1497
# #cite_ref-72
# https://usda.library.cornell.edu/concern/publications/1v53jw96n
# https://web.archive.org/web/20170426061324/http://usda.mannlib.cornell.edu/MannUsda/viewDocumentInfo.do?documentID=1509
# #cite_ref-73
# https://web.archive.org/web/20140529153518/http://www.worldwatch.org/towards-happier-meals-globalized-world
# http://www.worldwatch.org/towards-happier-meals-globalized-world
# #cite_ref-74
# /wiki/Doi_(identifier)
# https://doi.org/10.1007%2Fs10806-008-9136-3
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:154306257
# #cite_ref-75
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2002Natur.418..671T
# /wiki/Doi_(identifier)
# https://doi.org/10.1038%2Fnature01014
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/12167873
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:3016610
# #cite_ref-76
# https://www.animalsaustralia.org/factsheets/broiler_chickens.php
# https://web.archive.org/web/20100712123234/http://www.animalsaustralia.org/factsheets/broiler_chickens.php
# #cite_ref-77
# https://www.ciwf.org.uk/farm-animals/chickens/meat-chickens/
# #cite_ref-78
# https://www.egginfo.co.uk/egg-facts-and-figures/industry-information/data
# https://web.archive.org/web/20161230000509/https://www.egginfo.co.uk/egg-facts-and-figures/industry-information/data
# #cite_ref-79
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0440423102
# #cite_ref-Browne_80-0
# #cite_ref-Browne_80-1
# https://www.theguardian.com/lifeandstyle/2002/mar/10/foodanddrink.features1
# https://web.archive.org/web/20080516080228/http://observer.guardian.co.uk/foodmonthly/story/0,,662799,00.html
# #cite_ref-Patwardhan_and_King,_(2011)_81-0
# /wiki/Doi_(identifier)
# https://doi.org/10.1017%2Fs0043933911000286
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:88353703
# #cite_ref-Webster,_(2003)_82-0
# https://doi.org/10.1093%2Fps%2F82.6.992
# /wiki/Doi_(identifier)
# https://doi.org/10.1093%2Fps%2F82.6.992
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/27852011
# #cite_ref-99
# https://abcnews.go.com/Technology/story?id=1666805
# https://web.archive.org/web/20080620230515/https://abcnews.go.com/Technology/story?id=1666805
# /wiki/Wayback_Machine
# /wiki/ABC_News
# #cite_ref-smithsonianmag.com_100-0
# https://www.smithsonianmag.com/history/how-the-chicken-conquered-the-world-87583657/
# https://web.archive.org/web/20121103193648/http://www.smithsonianmag.com/history-archaeology/How-the-Chicken-Conquered-the-World.html
# #cite_ref-101
# https://books.google.com/books?id=vvVPAAAAMAAJ&q=Alectryomancy+cockfight&pg=PA394
# #cite_ref-102
# https://www.washingtonpost.com/archive/entertainment/books/1981/08/16/love-and-immolation-in-argentina/9cf0bdac-cfc3-4198-8824-d89d5e059c55/
# /wiki/Washington_Post
# #cite_ref-103
# #cite_ref-104
# https://web.archive.org/web/20240202161615/https://www.paintingworldmag.com/post/chickens-in-art-history
# https://www.paintingworldmag.com/post/chickens-in-art-history
# #cite_ref-105
# #cite_ref-106
# https://content.time.com/time/world/article/0,8599,2047283,00.html
# /wiki/ISSN_(identifier)
# https://www.worldcat.org/issn/0040-781X
# https://web.archive.org/web/20230124033415/https://content.time.com/time/world/article/0,8599,2047283,00.html
# #cite_ref-107
# https://catalog.afi.com/Catalog/moviedetails/61096
# https://web.archive.org/web/20180817060102/https://catalog.afi.com/Catalog/moviedetails/61096
# #cite_ref-108
# https://www.sfgate.com/movies/amp/Chicken-Recipe-Simply-Divine-Action-comedy-3239861.php
# https://web.archive.org/web/20210602214504/https://www.sfgate.com/movies/amp/Chicken-Recipe-Simply-Divine-Action-comedy-3239861.php
# https://commons.wikimedia.org/wiki/Category:Chickens
# /wiki/File:Wikispecies-logo.svg
# https://species.wikimedia.org/wiki/Gallus_gallus_domesticus
# /wiki/Template:Chicken
# /wiki/Template_talk:Chicken
# /wiki/Special:EditPage/Template:Chicken
# /wiki/Poultry
# /wiki/Chicken_as_food
# /wiki/List_of_chicken_dishes
# /wiki/List_of_chicken_breeds
# /wiki/Capon
# /wiki/Poularde
# /wiki/Poussin_(chicken)
# /wiki/Broiler
# /wiki/Chicken_terminology
# /wiki/List_of_chicken_colours
# /wiki/List_of_poultry_feathers
# /wiki/Chicken_farming
# /wiki/Battery_cage
# /wiki/Free_range
# /wiki/Furnished_cages
# /wiki/Yarding
# /wiki/Chicken_tractor
# /wiki/Poultry_farming
# /wiki/Broiler_industry
# /wiki/Debeaking
# /wiki/Forced_molting
# /wiki/Hatchery
# /wiki/Chick_sexing
# /wiki/Chick_culling
# /wiki/Candling
# /wiki/Abnormal_behaviour_of_birds_in_captivity
# /wiki/European_Union_Council_Directive_1999/74/EC
# /wiki/Cultural_references_to_chickens
# /wiki/Chickens_as_pets
# /wiki/Cockatrice
# /wiki/Cockfight
# /wiki/Kapparot
# /wiki/Sarimanok
# /wiki/Cock_flag
# /wiki/Chicken_disease
# /wiki/Aspergillosis
# /wiki/Gallid_alphaherpesvirus_1
# /wiki/Avian_influenza
# /wiki/Avian_sarcoma_leukosis_virus
# /wiki/Histomoniasis
# /wiki/Botulism
# /wiki/Campylobacteriosis
# /wiki/Candidiasis
# /wiki/Coccidia
# /wiki/Common_cold
# /wiki/Dermanyssus_gallinae
# /wiki/Egg_binding
# /wiki/Erysipelas
# /wiki/Fatty_liver_hemorrhagic_syndrome
# /wiki/Fowlpox
# /wiki/Gallid_alphaherpesvirus_3
# /wiki/Gapeworm
# /wiki/Infectious_bursal_disease
# /wiki/Infectious_coryza_in_chickens
# /wiki/Chicken_malaria
# /wiki/Marek%27s_disease
# /wiki/Mycoplasma
# /wiki/Newcastle_disease
# /wiki/Omphalitis
# /wiki/Psittacosis
# /wiki/Salmonella
# /wiki/Scaly_leg
# /wiki/Squamous_cell_carcinoma
# /wiki/Tibial_dyschondroplasia
# /wiki/Toxoplasmosis
# /wiki/Template:Poultry
# /wiki/Template_talk:Poultry
# /wiki/Special:EditPage/Template:Poultry
# /wiki/Poultry
# /wiki/Domestic_duck
# /wiki/Domestic_goose
# /wiki/Domestic_guineafowl
# /wiki/Grey_partridge
# /wiki/Common_pheasant
# /wiki/Domestic_pigeon
# /wiki/Common_quail
# /wiki/Japanese_quail
# /wiki/Domestic_turkey
# /wiki/Lists_of_poultry_breeds
# /wiki/List_of_chicken_breeds
# /wiki/List_of_duck_breeds
# /wiki/List_of_turkey_breeds
# /wiki/List_of_goose_breeds
# /wiki/List_of_pigeon_breeds
# /wiki/Poultry_disease
# /wiki/Fowlpox
# /wiki/Poultry_malaria
# /wiki/Scaly_leg
# /wiki/Poultry_farming
# /wiki/Antibiotics_in_poultry_farming
# /wiki/Battery_cage
# /wiki/Blinders_(poultry)
# /wiki/Cannibalism_in_poultry
# /wiki/Chicken_eyeglasses
# /wiki/Chick_culling
# /wiki/Chick_sexing
# /wiki/Chicken_coop
# /wiki/Chicken_harvester
# /wiki/Debeaking
# /wiki/Forced_molting
# /wiki/Free_range
# /wiki/Free-range_eggs
# /wiki/Furnished_cages
# /wiki/Hatchery
# /wiki/Hock_burns
# /wiki/Organic_egg_production
# /wiki/Pastured_poultry
# /wiki/Poultry_litter
# /wiki/Poultry_farming_in_the_United_States
# /wiki/Yarding
# /wiki/Help:Taxon_identifiers
# /wiki/Wikidata
# https://www.wikidata.org/wiki/Q780
# /wiki/EPPO_Code
# https://gd.eppo.int/taxon/GALUDO
# /wiki/Global_Biodiversity_Information_Facility
# https://www.gbif.org/species/9457155
# /wiki/INaturalist
# https://inaturalist.org/taxa/505478
# /wiki/National_Biodiversity_Network
# https://data.nbn.org.uk/Taxa/NHMSYS0020975169
# https://www.nzor.org.nz/names/00228927-f07c-4b05-8012-b9e8fb65eb3c
# https://de.wikipedia.org/wiki/Tierstimmenarchiv
# http://www.tierstimmen.org/en/database?field_spec_species_target_id_selective=7267
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q780#identifiers
# https://catalogue.bnf.fr/ark:/12148/cb119759480
# https://data.bnf.fr/ark:/12148/cb119759480
# https://d-nb.info/gnd/4026126-8
# http://olduli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007285684105171
# https://id.loc.gov/authorities/sh85023298
# https://id.ndl.go.jp/auth/ndlna/00568580
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=ph685408&CON_LNG=ENG
# https://en.wikipedia.org/w/index.php?title=Chicken&oldid=1209576901
# /wiki/Help:Category
# /wiki/Category:Domesticated_animals
# /wiki/Category:Chickens
# /wiki/Category:Birds_described_in_1758
# /wiki/Category:Bird_common_names
# /wiki/Category:Taxa_named_by_Carl_Linnaeus
# /wiki/Category:Junglefowls
# /wiki/Category:Poultry
# /wiki/Category:Subspecies
# /wiki/Category:Cosmopolitan_birds
# /wiki/Category:National_symbols_of_Kenya
# /wiki/Category:Heraldic_beasts
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:All_articles_with_dead_external_links
# /wiki/Category:Articles_with_dead_external_links_from_February_2022
# /wiki/Category:Articles_with_permanently_dead_external_links
# /wiki/Category:Good_articles
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# /wiki/Category:Wikipedia_indefinitely_move-protected_pages
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Use_mdy_dates_from_September_2023
# /wiki/Category:Articles_with_%27species%27_microformats
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2018
# /wiki/Category:All_articles_containing_potentially_dated_statements
# /wiki/Category:Commons_category_link_is_on_Wikidata
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_BNFdata_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_NDL_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# /wiki/Category:Articles_containing_video_clips
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Chicken&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# This is a great start! You can see we have _lots_ of internal Wikipedia links (links to other Wikipedia articles).. This could be the start of a Wikipedia specific crawler.
#
# The links which start with a `#` are references to breakpoints on the page, so that you could send the link to someone already scrolled to a specific point on the page.
#
# Now I want to just grab all the Wikipedia links and filter everything else out.

# %%
filtered = [link for link in links if link.startswith('/wiki/')]

for f in filtered:
    print(f)
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# /wiki/Chicken
# /wiki/Talk:Chicken
# /wiki/Chicken
# /wiki/Chicken
# /wiki/Special:WhatLinksHere/Chicken
# /wiki/Special:RecentChangesLinked/Chicken
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /wiki/Wikipedia:Good_articles*
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Chicken_as_food
# /wiki/Chicken_(disambiguation)
# /wiki/Chooks_(disambiguation)
# /wiki/Rooster_(disambiguation)
# /wiki/Cockerel_(Faberg%C3%A9_egg)
# /wiki/File:Male_and_female_chicken_sitting_together.jpg
# /wiki/Conservation_status
# /wiki/Taxonomy_(biology)
# /wiki/Template:Taxonomy/Gallus
# /wiki/Eukaryote
# /wiki/Animal
# /wiki/Chordate
# /wiki/Bird
# /wiki/Galliformes
# /wiki/Phasianidae
# /wiki/Junglefowl
# /wiki/Binomial_nomenclature
# /wiki/Carl_Linnaeus
# /wiki/10th_edition_of_Systema_Naturae
# /wiki/File:GLW_2_global_distributions_of_c)_chickens.tif
# /wiki/Synonym_(taxonomy)
# /wiki/L.
# /wiki/Domestication
# /wiki/Red_junglefowl
# /wiki/Southeast_Asia
# /wiki/Chicken_as_food
# /wiki/Egg_as_food
# /wiki/Pet
# /wiki/Cockfight
# /wiki/Cultural_references_to_chickens
# /wiki/Capon
# /wiki/Neutered
# /wiki/Chick_(young_bird)
# /wiki/Help:IPA/English
# /wiki/Hen_and_Chicken_Islands
# /wiki/File:Rooster_portrait2.jpg
# /wiki/Comb_(anatomy)
# /wiki/File:Hen_Comb_(cropped).jpg
# /wiki/Bird
# /wiki/Diurnality
# /wiki/Junglefowl
# /wiki/Bird_flight
# /wiki/Flight_muscle
# /wiki/Wattle_(anatomy)
# /wiki/Sexual_dimorphism
# /wiki/Mutation
# /wiki/Omnivore
# /wiki/Lizard
# /wiki/Mouse
# /wiki/Breed
# /wiki/Gregarious
# /wiki/Herd
# /wiki/Egg_incubation
# /wiki/Dominance_hierarchy
# /wiki/Thorleif_Schjelderup-Ebbe
# /wiki/Warning_call
# /wiki/Predation
# /wiki/Cloaca
# /wiki/Neuroendocrine_cell
# /wiki/Gonadotropin-Releasing_Hormone-I_neuron
# /wiki/Hypothalamus
# /wiki/Estrogen
# /wiki/Progesterone
# /wiki/Gonadotropin
# /wiki/Luteinizing_hormone
# /wiki/Follicle-stimulating_hormone
# /wiki/File:Newly-hatched_chickens.jpg
# /wiki/Clutch_(eggs)
# /wiki/Broodiness
# /wiki/Tibet
# /wiki/Hemoglobin
# /wiki/Egg_tooth
# /wiki/Yolk_sac
# /wiki/Imprinting_(psychology)
# /wiki/File:Red_Junglefowl.jpg
# /wiki/Red_junglefowl
# /wiki/Partridge
# /wiki/Galliformes
# /wiki/Order_(biology)
# /wiki/Cretaceous%E2%80%93Paleogene_extinction_event
# /wiki/Dinosaur
# /wiki/Red_junglefowl
# /wiki/Grey_junglefowl
# /wiki/Sri_Lankan_junglefowl
# /wiki/Green_junglefowl
# /wiki/Domestication
# /wiki/File:Chicken_domestication_and_dispersal.svg
# /wiki/Thailand
# /wiki/Bamboo#Mass_flowering
# /wiki/Bamboo#Mass_flowering
# /wiki/File:Map_showing_prehistoric_diffusion_of_domestic_chickens_(Gallus_gallus)_into_the_Pacific_via_the_Austronesian_migrations_(Thomson,_Lebrasseur,_%26_Austin,_2014).png
# /wiki/Oceania
# /wiki/Philippines
# /wiki/Neolithic
# /wiki/Austronesian_expansion
# /wiki/Before_present
# /wiki/Proto-Austronesian_language
# /wiki/Domesticated_plants_and_animals_of_Austronesia
# /wiki/Austronesian_peoples
# /wiki/Island_Southeast_Asia
# /wiki/Micronesia
# /wiki/Island_Melanesia
# /wiki/Polynesia
# /wiki/Madagascar
# /wiki/Indigenous_Taiwanese
# /wiki/Pre-Columbian
# /wiki/South_America
# /wiki/Polynesians
# /wiki/Syria
# /wiki/Cockfighting
# /wiki/Hellenistic_period
# /wiki/Levant
# /wiki/Corinth,_Greece
# /wiki/Pottery
# /wiki/Roman_Empire
# /wiki/Middle_Ages
# /wiki/DNA_sequencing
# /wiki/High_Middle_Ages
# /wiki/Nile_River
# /wiki/Sahara_Desert
# /wiki/Extinction
# /wiki/Arauco_Peninsula
# /wiki/Zona_Sur
# /wiki/Poultry_disease
# /wiki/File:Pesse_oujheas_H9N2_tanfla.JPG
# /wiki/Avian_influenza
# /wiki/Parasitism
# /wiki/Mite
# /wiki/Poultry_disease
# /wiki/Pathogen
# /wiki/Bacteria
# /wiki/Virus
# /wiki/Dermanyssus_gallinae
# /wiki/Salmonellosis
# /wiki/Borrelia_anserina
# /wiki/Avian_influenza
# /wiki/Poultry_farming
# /wiki/Intensive_animal_farming
# /wiki/Worldwatch_Institute
# /wiki/Free-range
# /wiki/Ethical_consumerism
# /wiki/Intensive_farming
# /wiki/Broiler
# /wiki/Free_range
# /wiki/Organic_(food)
# /wiki/File:Florida_chicken_house.jpg
# /wiki/Battery_cage
# /wiki/Forced_molting
# /wiki/Silkie
# /wiki/Bantam_(poultry)
# /wiki/Cockfight
# /wiki/File:COCK_FIGHT.JPG
# /wiki/Cockfight
# /wiki/Tamil_Nadu
# /wiki/Cockfight
# /wiki/Cruelty_to_animals
# /wiki/Indus_Valley_civilisation
# /wiki/Model_organism
# /wiki/Limb_development
# /wiki/Apical_ectodermal_ridge
# /wiki/Zone_of_polarizing_activity
# /wiki/Genome
# /wiki/Human_genome
# /wiki/Pseudogene
# /wiki/Recessive_gene
# /wiki/Cultural_references_to_chickens
# /wiki/Folklore
# /wiki/Religion
# /wiki/Literature
# /wiki/Divination
# /wiki/Cockfight
# /wiki/Gabriel_Garc%C3%ADa_M%C3%A1rquez
# /wiki/One_Hundred_Years_Of_Solitude
# /wiki/Chicken_joke
# /wiki/The_Knickerbocker
# /wiki/Adriaen_van_Utrecht
# /wiki/Walter_Osborne
# /wiki/Nursery_rhyme
# /wiki/Cock_a_doodle_doo
# /wiki/Mother_Goose%27s_Melody
# /wiki/Adventure_film
# /wiki/Comedy_film
# /wiki/Chicken_Run
# /wiki/Peter_Lord
# /wiki/Nick_Park
# /wiki/Anthropomorphism
# /wiki/File:Terracotta_askos_(flask)_in_the_form_of_a_rooster_MET_DP252108_(cropped).jpg
# /wiki/Etruscan_civilization
# /wiki/File:Rooster_and_hen,_Dong_Ho_picture,_paper_-_Vietnam_National_Museum_of_Fine_Arts_-_Hanoi,_Vietnam_-_DSC05287.JPG
# /wiki/%C4%90%C3%B4ng_H%E1%BB%93_painting
# /wiki/File:Feeding_the_chickens,_by_Walter_Frederick_Osborne.jpg
# /wiki/Walter_Osborne
# /wiki/File:Joseph_Crawhall_-_Spanish_Cock_And_Snail.jpg
# /wiki/Joseph_Crawhall_III
# /wiki/File:Chicken_Mask_Bali.jpg
# /wiki/Bali
# /wiki/File:Yoruba_Cockfight.jpg
# /wiki/Yoruba_culture
# /wiki/Wayback_Machine
# /wiki/Wayback_Machine
# /wiki/University_of_Pennsylvania_Press
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-8122-8018-0
# /wiki/OCLC_(identifier)
# /wiki/Wayback_Machine
# /wiki/Doi_(identifier)
# /wiki/YouTube
# /wiki/Tuscaloosa_News
# /wiki/Doi_(identifier)
# /wiki/JSTOR_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Temple_Grandin
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-7432-4769-6
# /wiki/Doi_(identifier)
# /wiki/JSTOR_(identifier)
# /wiki/Doi_(identifier)
# /wiki/JSTOR_(identifier)
# /wiki/Taylor_%26_Francis
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Elizabeth_Pennisi
# /wiki/Doi_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9781760460945
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9780521003544
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9780521546973
# /wiki/Cambridge_University_Press
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9780781811460
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9780313334108
# /wiki/ISSN_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Atholl_Anderson
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/ISSN_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0440423102
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Hdl_(identifier)
# /wiki/Doi_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Chicago_Tribune
# /wiki/Wikipedia:Link_rot
# /wiki/Boston_Globe
# /wiki/Los_Angeles_Times
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0444885579
# /wiki/OL_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMID_(identifier)
# /wiki/S2CID_(identifier)
# /wiki/Doi_(identifier)
# /wiki/PMC_(identifier)
# /wiki/PMID_(identifier)
# /wiki/Wayback_Machine
# /wiki/ABC_News
# /wiki/Washington_Post
# /wiki/ISSN_(identifier)
# /wiki/File:Wikispecies-logo.svg
# /wiki/Template:Chicken
# /wiki/Template_talk:Chicken
# /wiki/Special:EditPage/Template:Chicken
# /wiki/Poultry
# /wiki/Chicken_as_food
# /wiki/List_of_chicken_dishes
# /wiki/List_of_chicken_breeds
# /wiki/Capon
# /wiki/Poularde
# /wiki/Poussin_(chicken)
# /wiki/Broiler
# /wiki/Chicken_terminology
# /wiki/List_of_chicken_colours
# /wiki/List_of_poultry_feathers
# /wiki/Chicken_farming
# /wiki/Battery_cage
# /wiki/Free_range
# /wiki/Furnished_cages
# /wiki/Yarding
# /wiki/Chicken_tractor
# /wiki/Poultry_farming
# /wiki/Broiler_industry
# /wiki/Debeaking
# /wiki/Forced_molting
# /wiki/Hatchery
# /wiki/Chick_sexing
# /wiki/Chick_culling
# /wiki/Candling
# /wiki/Abnormal_behaviour_of_birds_in_captivity
# /wiki/European_Union_Council_Directive_1999/74/EC
# /wiki/Cultural_references_to_chickens
# /wiki/Chickens_as_pets
# /wiki/Cockatrice
# /wiki/Cockfight
# /wiki/Kapparot
# /wiki/Sarimanok
# /wiki/Cock_flag
# /wiki/Chicken_disease
# /wiki/Aspergillosis
# /wiki/Gallid_alphaherpesvirus_1
# /wiki/Avian_influenza
# /wiki/Avian_sarcoma_leukosis_virus
# /wiki/Histomoniasis
# /wiki/Botulism
# /wiki/Campylobacteriosis
# /wiki/Candidiasis
# /wiki/Coccidia
# /wiki/Common_cold
# /wiki/Dermanyssus_gallinae
# /wiki/Egg_binding
# /wiki/Erysipelas
# /wiki/Fatty_liver_hemorrhagic_syndrome
# /wiki/Fowlpox
# /wiki/Gallid_alphaherpesvirus_3
# /wiki/Gapeworm
# /wiki/Infectious_bursal_disease
# /wiki/Infectious_coryza_in_chickens
# /wiki/Chicken_malaria
# /wiki/Marek%27s_disease
# /wiki/Mycoplasma
# /wiki/Newcastle_disease
# /wiki/Omphalitis
# /wiki/Psittacosis
# /wiki/Salmonella
# /wiki/Scaly_leg
# /wiki/Squamous_cell_carcinoma
# /wiki/Tibial_dyschondroplasia
# /wiki/Toxoplasmosis
# /wiki/Template:Poultry
# /wiki/Template_talk:Poultry
# /wiki/Special:EditPage/Template:Poultry
# /wiki/Poultry
# /wiki/Domestic_duck
# /wiki/Domestic_goose
# /wiki/Domestic_guineafowl
# /wiki/Grey_partridge
# /wiki/Common_pheasant
# /wiki/Domestic_pigeon
# /wiki/Common_quail
# /wiki/Japanese_quail
# /wiki/Domestic_turkey
# /wiki/Lists_of_poultry_breeds
# /wiki/List_of_chicken_breeds
# /wiki/List_of_duck_breeds
# /wiki/List_of_turkey_breeds
# /wiki/List_of_goose_breeds
# /wiki/List_of_pigeon_breeds
# /wiki/Poultry_disease
# /wiki/Fowlpox
# /wiki/Poultry_malaria
# /wiki/Scaly_leg
# /wiki/Poultry_farming
# /wiki/Antibiotics_in_poultry_farming
# /wiki/Battery_cage
# /wiki/Blinders_(poultry)
# /wiki/Cannibalism_in_poultry
# /wiki/Chicken_eyeglasses
# /wiki/Chick_culling
# /wiki/Chick_sexing
# /wiki/Chicken_coop
# /wiki/Chicken_harvester
# /wiki/Debeaking
# /wiki/Forced_molting
# /wiki/Free_range
# /wiki/Free-range_eggs
# /wiki/Furnished_cages
# /wiki/Hatchery
# /wiki/Hock_burns
# /wiki/Organic_egg_production
# /wiki/Pastured_poultry
# /wiki/Poultry_litter
# /wiki/Poultry_farming_in_the_United_States
# /wiki/Yarding
# /wiki/Help:Taxon_identifiers
# /wiki/Wikidata
# /wiki/EPPO_Code
# /wiki/Global_Biodiversity_Information_Facility
# /wiki/INaturalist
# /wiki/National_Biodiversity_Network
# /wiki/Help:Authority_control
# /wiki/Help:Category
# /wiki/Category:Domesticated_animals
# /wiki/Category:Chickens
# /wiki/Category:Birds_described_in_1758
# /wiki/Category:Bird_common_names
# /wiki/Category:Taxa_named_by_Carl_Linnaeus
# /wiki/Category:Junglefowls
# /wiki/Category:Poultry
# /wiki/Category:Subspecies
# /wiki/Category:Cosmopolitan_birds
# /wiki/Category:National_symbols_of_Kenya
# /wiki/Category:Heraldic_beasts
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:All_articles_with_dead_external_links
# /wiki/Category:Articles_with_dead_external_links_from_February_2022
# /wiki/Category:Articles_with_permanently_dead_external_links
# /wiki/Category:Good_articles
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# /wiki/Category:Wikipedia_indefinitely_move-protected_pages
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Use_mdy_dates_from_September_2023
# /wiki/Category:Articles_with_%27species%27_microformats
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2018
# /wiki/Category:All_articles_containing_potentially_dated_statements
# /wiki/Category:Commons_category_link_is_on_Wikidata
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_BNFdata_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_NDL_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# /wiki/Category:Articles_containing_video_clips
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer

# %% [markdown]
# That got all internal Wikipedia links, but there are also images (`.jpg`, `.png`, `.tif`) in there. There are also a bunch of other things so I am gonna do that again. The cell below does the same check above, but then also checks if any of the other junk I don't want is in the link, and of course skips it if so.

# %%
ignores = ['png', 'jpg', 'jpeg', 'isbn', 'svg', 'identifier', \
           'File', 'Special', 'Template', 'Mailto', 'Portal', \
           'Help', 'Category', 'Talk', 'Wikipedia', 'Main_Page']

filtered = []

for link in links:
    if link.startswith('/wiki/'):
        valid = True
        for ignore in ignores:
            if ignore in link:
                valid = False
                break
        if valid:
            filtered.append(link)

for f in filtered:
    print(f)
# Out:
# /wiki/Chicken
# /wiki/Chicken
# /wiki/Chicken
# /wiki/Chicken_as_food
# /wiki/Chicken_(disambiguation)
# /wiki/Chooks_(disambiguation)
# /wiki/Rooster_(disambiguation)
# /wiki/Cockerel_(Faberg%C3%A9_egg)
# /wiki/Conservation_status
# /wiki/Taxonomy_(biology)
# /wiki/Eukaryote
# /wiki/Animal
# /wiki/Chordate
# /wiki/Bird
# /wiki/Galliformes
# /wiki/Phasianidae
# /wiki/Junglefowl
# /wiki/Binomial_nomenclature
# /wiki/Carl_Linnaeus
# /wiki/10th_edition_of_Systema_Naturae
# /wiki/Synonym_(taxonomy)
# /wiki/L.
# /wiki/Domestication
# /wiki/Red_junglefowl
# /wiki/Southeast_Asia
# /wiki/Chicken_as_food
# /wiki/Egg_as_food
# /wiki/Pet
# /wiki/Cockfight
# /wiki/Cultural_references_to_chickens
# /wiki/Capon
# /wiki/Neutered
# /wiki/Chick_(young_bird)
# /wiki/Hen_and_Chicken_Islands
# /wiki/Comb_(anatomy)
# /wiki/Bird
# /wiki/Diurnality
# /wiki/Junglefowl
# /wiki/Bird_flight
# /wiki/Flight_muscle
# /wiki/Wattle_(anatomy)
# /wiki/Sexual_dimorphism
# /wiki/Mutation
# /wiki/Omnivore
# /wiki/Lizard
# /wiki/Mouse
# /wiki/Breed
# /wiki/Gregarious
# /wiki/Herd
# /wiki/Egg_incubation
# /wiki/Dominance_hierarchy
# /wiki/Thorleif_Schjelderup-Ebbe
# /wiki/Warning_call
# /wiki/Predation
# /wiki/Cloaca
# /wiki/Neuroendocrine_cell
# /wiki/Gonadotropin-Releasing_Hormone-I_neuron
# /wiki/Hypothalamus
# /wiki/Estrogen
# /wiki/Progesterone
# /wiki/Gonadotropin
# /wiki/Luteinizing_hormone
# /wiki/Follicle-stimulating_hormone
# /wiki/Clutch_(eggs)
# /wiki/Broodiness
# /wiki/Tibet
# /wiki/Hemoglobin
# /wiki/Egg_tooth
# /wiki/Yolk_sac
# /wiki/Imprinting_(psychology)
# /wiki/Red_junglefowl
# /wiki/Partridge
# /wiki/Galliformes
# /wiki/Order_(biology)
# /wiki/Cretaceous%E2%80%93Paleogene_extinction_event
# /wiki/Dinosaur
# /wiki/Red_junglefowl
# /wiki/Grey_junglefowl
# /wiki/Sri_Lankan_junglefowl
# /wiki/Green_junglefowl
# /wiki/Domestication
# /wiki/Thailand
# /wiki/Bamboo#Mass_flowering
# /wiki/Bamboo#Mass_flowering
# /wiki/Oceania
# /wiki/Philippines
# /wiki/Neolithic
# /wiki/Austronesian_expansion
# /wiki/Before_present
# /wiki/Proto-Austronesian_language
# /wiki/Domesticated_plants_and_animals_of_Austronesia
# /wiki/Austronesian_peoples
# /wiki/Island_Southeast_Asia
# /wiki/Micronesia
# /wiki/Island_Melanesia
# /wiki/Polynesia
# /wiki/Madagascar
# /wiki/Indigenous_Taiwanese
# /wiki/Pre-Columbian
# /wiki/South_America
# /wiki/Polynesians
# /wiki/Syria
# /wiki/Cockfighting
# /wiki/Hellenistic_period
# /wiki/Levant
# /wiki/Corinth,_Greece
# /wiki/Pottery
# /wiki/Roman_Empire
# /wiki/Middle_Ages
# /wiki/DNA_sequencing
# /wiki/High_Middle_Ages
# /wiki/Nile_River
# /wiki/Sahara_Desert
# /wiki/Extinction
# /wiki/Arauco_Peninsula
# /wiki/Zona_Sur
# /wiki/Poultry_disease
# /wiki/Avian_influenza
# /wiki/Parasitism
# /wiki/Mite
# /wiki/Poultry_disease
# /wiki/Pathogen
# /wiki/Bacteria
# /wiki/Virus
# /wiki/Dermanyssus_gallinae
# /wiki/Salmonellosis
# /wiki/Borrelia_anserina
# /wiki/Avian_influenza
# /wiki/Poultry_farming
# /wiki/Intensive_animal_farming
# /wiki/Worldwatch_Institute
# /wiki/Free-range
# /wiki/Ethical_consumerism
# /wiki/Intensive_farming
# /wiki/Broiler
# /wiki/Free_range
# /wiki/Organic_(food)
# /wiki/Battery_cage
# /wiki/Forced_molting
# /wiki/Silkie
# /wiki/Bantam_(poultry)
# /wiki/Cockfight
# /wiki/Cockfight
# /wiki/Tamil_Nadu
# /wiki/Cockfight
# /wiki/Cruelty_to_animals
# /wiki/Indus_Valley_civilisation
# /wiki/Model_organism
# /wiki/Limb_development
# /wiki/Apical_ectodermal_ridge
# /wiki/Zone_of_polarizing_activity
# /wiki/Genome
# /wiki/Human_genome
# /wiki/Pseudogene
# /wiki/Recessive_gene
# /wiki/Cultural_references_to_chickens
# /wiki/Folklore
# /wiki/Religion
# /wiki/Literature
# /wiki/Divination
# /wiki/Cockfight
# /wiki/Gabriel_Garc%C3%ADa_M%C3%A1rquez
# /wiki/One_Hundred_Years_Of_Solitude
# /wiki/Chicken_joke
# /wiki/The_Knickerbocker
# /wiki/Adriaen_van_Utrecht
# /wiki/Walter_Osborne
# /wiki/Nursery_rhyme
# /wiki/Cock_a_doodle_doo
# /wiki/Mother_Goose%27s_Melody
# /wiki/Adventure_film
# /wiki/Comedy_film
# /wiki/Chicken_Run
# /wiki/Peter_Lord
# /wiki/Nick_Park
# /wiki/Anthropomorphism
# /wiki/Etruscan_civilization
# /wiki/%C4%90%C3%B4ng_H%E1%BB%93_painting
# /wiki/Walter_Osborne
# /wiki/Joseph_Crawhall_III
# /wiki/Bali
# /wiki/Yoruba_culture
# /wiki/Wayback_Machine
# /wiki/Wayback_Machine
# /wiki/University_of_Pennsylvania_Press
# /wiki/Wayback_Machine
# /wiki/YouTube
# /wiki/Tuscaloosa_News
# /wiki/Temple_Grandin
# /wiki/Taylor_%26_Francis
# /wiki/Elizabeth_Pennisi
# /wiki/Cambridge_University_Press
# /wiki/Atholl_Anderson
# /wiki/Chicago_Tribune
# /wiki/Boston_Globe
# /wiki/Los_Angeles_Times
# /wiki/Wayback_Machine
# /wiki/ABC_News
# /wiki/Washington_Post
# /wiki/Poultry
# /wiki/Chicken_as_food
# /wiki/List_of_chicken_dishes
# /wiki/List_of_chicken_breeds
# /wiki/Capon
# /wiki/Poularde
# /wiki/Poussin_(chicken)
# /wiki/Broiler
# /wiki/Chicken_terminology
# /wiki/List_of_chicken_colours
# /wiki/List_of_poultry_feathers
# /wiki/Chicken_farming
# /wiki/Battery_cage
# /wiki/Free_range
# /wiki/Furnished_cages
# /wiki/Yarding
# /wiki/Chicken_tractor
# /wiki/Poultry_farming
# /wiki/Broiler_industry
# /wiki/Debeaking
# /wiki/Forced_molting
# /wiki/Hatchery
# /wiki/Chick_sexing
# /wiki/Chick_culling
# /wiki/Candling
# /wiki/Abnormal_behaviour_of_birds_in_captivity
# /wiki/European_Union_Council_Directive_1999/74/EC
# /wiki/Cultural_references_to_chickens
# /wiki/Chickens_as_pets
# /wiki/Cockatrice
# /wiki/Cockfight
# /wiki/Kapparot
# /wiki/Sarimanok
# /wiki/Cock_flag
# /wiki/Chicken_disease
# /wiki/Aspergillosis
# /wiki/Gallid_alphaherpesvirus_1
# /wiki/Avian_influenza
# /wiki/Avian_sarcoma_leukosis_virus
# /wiki/Histomoniasis
# /wiki/Botulism
# /wiki/Campylobacteriosis
# /wiki/Candidiasis
# /wiki/Coccidia
# /wiki/Common_cold
# /wiki/Dermanyssus_gallinae
# /wiki/Egg_binding
# /wiki/Erysipelas
# /wiki/Fatty_liver_hemorrhagic_syndrome
# /wiki/Fowlpox
# /wiki/Gallid_alphaherpesvirus_3
# /wiki/Gapeworm
# /wiki/Infectious_bursal_disease
# /wiki/Infectious_coryza_in_chickens
# /wiki/Chicken_malaria
# /wiki/Marek%27s_disease
# /wiki/Mycoplasma
# /wiki/Newcastle_disease
# /wiki/Omphalitis
# /wiki/Psittacosis
# /wiki/Salmonella
# /wiki/Scaly_leg
# /wiki/Squamous_cell_carcinoma
# /wiki/Tibial_dyschondroplasia
# /wiki/Toxoplasmosis
# /wiki/Poultry
# /wiki/Domestic_duck
# /wiki/Domestic_goose
# /wiki/Domestic_guineafowl
# /wiki/Grey_partridge
# /wiki/Common_pheasant
# /wiki/Domestic_pigeon
# /wiki/Common_quail
# /wiki/Japanese_quail
# /wiki/Domestic_turkey
# /wiki/Lists_of_poultry_breeds
# /wiki/List_of_chicken_breeds
# /wiki/List_of_duck_breeds
# /wiki/List_of_turkey_breeds
# /wiki/List_of_goose_breeds
# /wiki/List_of_pigeon_breeds
# /wiki/Poultry_disease
# /wiki/Fowlpox
# /wiki/Poultry_malaria
# /wiki/Scaly_leg
# /wiki/Poultry_farming
# /wiki/Antibiotics_in_poultry_farming
# /wiki/Battery_cage
# /wiki/Blinders_(poultry)
# /wiki/Cannibalism_in_poultry
# /wiki/Chicken_eyeglasses
# /wiki/Chick_culling
# /wiki/Chick_sexing
# /wiki/Chicken_coop
# /wiki/Chicken_harvester
# /wiki/Debeaking
# /wiki/Forced_molting
# /wiki/Free_range
# /wiki/Free-range_eggs
# /wiki/Furnished_cages
# /wiki/Hatchery
# /wiki/Hock_burns
# /wiki/Organic_egg_production
# /wiki/Pastured_poultry
# /wiki/Poultry_litter
# /wiki/Poultry_farming_in_the_United_States
# /wiki/Yarding
# /wiki/Wikidata
# /wiki/EPPO_Code
# /wiki/Global_Biodiversity_Information_Facility
# /wiki/INaturalist
# /wiki/National_Biodiversity_Network

# %% [markdown]
# An alternative way to find links with a particular pattern would be to use [regular expression](https://www.regular-expressions.info/#:~:text=A%20regular%20expression%20(regex%20or,with%20wildcard%20notations%20such%20as%20*)

# %% [markdown]
# #### <span style="color:red"> Exercise 1 </span>
#
# practice using beautiful soup and nltk get all the text html tag in the chicken page and count the number of time the word "chicken" is used There should be about ~ 184 occurrences

# %%
from nltk.tokenize import word_tokenize

url = 'https://en.wikipedia.org/wiki/chicken'
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
tokens = word_tokenize(soup.text)

query_word = "chicken"
word_count = 0

for i in tokens:
    if query_word == i.lower(): # or "in" instead of == picks up all chickens
        word_count += 1

print(word_count)
# Out:
# 76

# %% [markdown]
# #### <span style="color:red"> Exercise 2 </span>
#
# Go over this [python doc](https://docs.python.org/3/library/re.html) and use regular expresssions to grab the links that have article. How does this improve the code?

# %% [markdown]
# We now have a good number of valid links to other Wikipedia articles..
#
# Now we can really start crawling! For now lets just choose a link at random and then see what that Wikipedia article has for us...

# %%
random_wiki = random.choice(filtered)
url = url = 'https://en.wikipedia.org' + random_wiki
page = requests.get(url)
soup = BeautifulSoup(page.content, features="html.parser")

print(f"URL: {url}")

new_links = []

for a in soup.find_all("a"):
    try:
        new_links.append(a["href"])
    except:
        pass
    
new_filtered = []

for link in new_links:
    if link.startswith('/wiki/'):
        valid = True
        for ignore in ignores:
            if ignore in link:
                valid = False
                # As soon as we know the link is not valid, there's is no point
                # checking the rest of the ignores, so we break:
                break
        if valid:
            new_filtered.append(link)
            
for f in new_filtered:
    print(f)
# Out:
# URL: https://en.wikipedia.org/wiki/Forced_molting
# /wiki/Forced_molting
# /wiki/Forced_molting
# /wiki/Forced_molting
# /wiki/Molting
# /wiki/Chicken
# /wiki/Feather
# /wiki/Eggshell
# /wiki/Intensive_farming
# /wiki/Vertical_integration
# /wiki/Poultry
# /wiki/Husbandry
# /wiki/Alfalfa
# /wiki/Sodium
# /wiki/Calcium
# /wiki/Iodine
# /wiki/Zinc
# /wiki/Department_for_Environment,_Food_and_Rural_Affairs
# /wiki/Corticosterone
# /wiki/Lymphocyte
# /wiki/Leukocyte
# /wiki/Salmonella
# /wiki/Chicken
# /wiki/Poultry
# /wiki/Chicken_as_food
# /wiki/List_of_chicken_dishes
# /wiki/List_of_chicken_breeds
# /wiki/Capon
# /wiki/Poularde
# /wiki/Poussin_(chicken)
# /wiki/Broiler
# /wiki/Chicken_terminology
# /wiki/List_of_chicken_colours
# /wiki/List_of_poultry_feathers
# /wiki/Chicken_farming
# /wiki/Battery_cage
# /wiki/Free_range
# /wiki/Furnished_cages
# /wiki/Yarding
# /wiki/Chicken_tractor
# /wiki/Poultry_farming
# /wiki/Broiler_industry
# /wiki/Debeaking
# /wiki/Hatchery
# /wiki/Chick_sexing
# /wiki/Chick_culling
# /wiki/Candling
# /wiki/Abnormal_behaviour_of_birds_in_captivity
# /wiki/European_Union_Council_Directive_1999/74/EC
# /wiki/Cultural_references_to_chickens
# /wiki/Chickens_as_pets
# /wiki/Cockatrice
# /wiki/Cockfight
# /wiki/Kapparot
# /wiki/Sarimanok
# /wiki/Cock_flag
# /wiki/Chicken_disease
# /wiki/Aspergillosis
# /wiki/Gallid_alphaherpesvirus_1
# /wiki/Avian_influenza
# /wiki/Avian_sarcoma_leukosis_virus
# /wiki/Histomoniasis
# /wiki/Botulism
# /wiki/Campylobacteriosis
# /wiki/Candidiasis
# /wiki/Coccidia
# /wiki/Common_cold
# /wiki/Dermanyssus_gallinae
# /wiki/Egg_binding
# /wiki/Erysipelas
# /wiki/Fatty_liver_hemorrhagic_syndrome
# /wiki/Fowlpox
# /wiki/Gallid_alphaherpesvirus_3
# /wiki/Gapeworm
# /wiki/Infectious_bursal_disease
# /wiki/Infectious_coryza_in_chickens
# /wiki/Chicken_malaria
# /wiki/Marek%27s_disease
# /wiki/Mycoplasma
# /wiki/Newcastle_disease
# /wiki/Omphalitis
# /wiki/Psittacosis
# /wiki/Salmonella
# /wiki/Scaly_leg
# /wiki/Squamous_cell_carcinoma
# /wiki/Tibial_dyschondroplasia
# /wiki/Toxoplasmosis

# %% [markdown]
# This is OK.. but we are just repeating ourselves (it isn't very [DRY](... add link to DRY ...)), and this doesn't really set us up to automate the process.
#
# Let's turn these mini routines into functions.

# %%
def get_soup(wiki_suffix):
    url = url = 'https://en.wikipedia.org' + wiki_suffix
    page = requests.get(url)
    soup = BeautifulSoup(page.content, features="html.parser")
    
    return soup

def link_is_valid(link):
    ignores = ['png', 'jpg', 'jpeg', 'isbn', 'svg', 'identifier', \
           'File', 'Special', 'Template', 'Mailto', 'Portal', \
           'Help', 'Category', 'Talk', 'Wikipedia', 'Main_Page']
    
    if link.startswith('/wiki/'):
        valid = True
        for ignore in ignores:
            if ignore in link:
                valid = False
                break
    return valid
    

def get_links(soup):
    links = []
    for a in soup.find_all("a"):
        try:
            link = a["href"]
            if link_is_valid(link):
                links.append(link)
        except:
            pass
    
    return links


def count_words(soup, word=str):
    word_count = 0
    tokens = word_tokenize(soup.text)
    for i in tokens:
        if i == word:
            word_count += 1
    return word_count

# %% [markdown]
# #### <span style="color:red"> Exercise 3 </span>
#
# Add a function that given a word in counts how many times it appears in page

# %% [markdown]
# We have compartmentalised the few small routines in the code above and _abstracted_ them away into functions which are concise and are pretty much self-explanatory by their function names. This is starting to feel much nicer.. And something we could begin to turn into _software_.

# %%
random_wiki = random.choice(filtered)
soup = get_soup(random_wiki)
links = get_links(soup)
num = count_words(soup, "and")
print(num)
for l in links:
    print(l)
# Out:
# 150
# /wiki/Genome
# /wiki/Genome
# /wiki/Genome
# /wiki/Introduction_to_genetics
# /wiki/Genome_(disambiguation)
# /wiki/Genetics
# /wiki/Chromosome
# /wiki/DNA
# /wiki/RNA
# /wiki/Heredity
# /wiki/Nucleotide
# /wiki/Mutation
# /wiki/Genetic_variation
# /wiki/Allele
# /wiki/Amino_acid
# /wiki/Outline_of_genetics
# /wiki/Index_of_genetics_articles
# /wiki/Introduction_to_genetics
# /wiki/History_of_genetics
# /wiki/Evolution
# /wiki/Molecular_evolution
# /wiki/Population_genetics
# /wiki/Mendelian_inheritance
# /wiki/Quantitative_genetics
# /wiki/Molecular_genetics
# /wiki/Geneticist
# /wiki/DNA_sequencing
# /wiki/Genetic_engineering
# /wiki/Genomics
# /wiki/Medical_genetics
# /wiki/Outline_of_genetics#Branches_of_genetics
# /wiki/Classical_genetics
# /wiki/Conservation_genetics
# /wiki/Cytogenetics
# /wiki/Ecological_genetics
# /wiki/Immunogenetics
# /wiki/Microbial_genetics
# /wiki/Molecular_genetics
# /wiki/Population_genetics
# /wiki/Quantitative_genetics
# /wiki/Personalized_medicine
# /wiki/Molecular_biology
# /wiki/Genetics
# /wiki/Nucleotide
# /wiki/DNA
# /wiki/RNA
# /wiki/RNA_virus
# /wiki/Non-coding_DNA
# /wiki/Junk_DNA
# /wiki/Mitochondrial_DNA
# /wiki/Mitochondrial_genome
# /wiki/Chloroplast_DNA
# /wiki/Genomics
# /wiki/Whole-genome_sequencing
# /wiki/Human_Genome_Project
# /wiki/Human_genome
# /wiki/Hans_Winkler
# /wiki/Botany
# /wiki/University_of_Hamburg
# /wiki/Oxford_Dictionaries_(website)
# /wiki/Online_Etymology_Dictionary
# /wiki/Gene
# /wiki/Chromosome
# /wiki/Omics
# /wiki/Biome
# /wiki/Rhizome
# /wiki/Chromosomes
# /wiki/Plasmid
# /wiki/Mitochondrion
# /wiki/Chloroplast
# /wiki/Ploidy
# /wiki/Whole_genome_sequencing
# /wiki/Genome_project
# /wiki/Nucleotide
# /wiki/Chromosome
# /wiki/Walter_Fiers
# /wiki/University_of_Ghent
# /wiki/Bacteriophage_MS2
# /wiki/Fred_Sanger
# /wiki/Phi-X174_phage
# /wiki/Haemophilus_influenzae
# /wiki/The_Institute_for_Genomic_Research
# /wiki/Saccharomyces_cerevisiae
# /wiki/Archaea
# /wiki/Methanococcus_jannaschii
# /wiki/US_National_Institutes_of_Health
# /wiki/Rice
# /wiki/Mus_musculus
# /wiki/Arabidopsis_thaliana
# /wiki/Puffer_fish
# /wiki/Escherichia_coli
# /wiki/Neanderthal
# /wiki/Archaic_humans
# /wiki/Toe_bone
# /wiki/Denisova_Cave
# /wiki/Massive_parallel_sequencing
# /wiki/Manteia_Predictive_Medicine
# /wiki/Human_genome
# /wiki/James_D._Watson
# /wiki/Human_Genome_Project
# /wiki/Physical_map_(genetics)#Linkage_map
# /wiki/Sequencing
# /wiki/Human_genome
# /wiki/Jean_Weissenbach
# /wiki/Genoscope
# /wiki/Reference_genome
# /wiki/Genealogy
# /wiki/Crowdsourcing
# /wiki/New_York_Genome_Center
# /wiki/Economies_of_scale
# /wiki/Citizen_science
# /wiki/Virus#Genome
# /wiki/RNA_virus
# /wiki/Single-stranded_RNA_virus
# /wiki/Double-stranded_RNA_viruses
# /wiki/Circular_chromosome
# /wiki/Symbiotic_bacteria
# /wiki/Serratia_symbiotica
# /wiki/Plasmid
# /wiki/Eukaryotic_chromosome_fine_structure
# /wiki/Autosome
# /wiki/Sex_chromosomes
# /wiki/Human_mitochondrial_genetics
# /wiki/Karyotype
# /wiki/Jack_jumper_ant
# /wiki/Diploscapter_pachys
# /wiki/Ophioglossum
# /wiki/Autosome
# /wiki/Sex_chromosome
# /wiki/Gamete
# /wiki/Chloroplasts
# /wiki/Mitochondria
# /wiki/Mitochondrial_genome
# /wiki/Plastome
# /wiki/Non-coding_DNA
# /wiki/Intergenic_region
# /wiki/Intron
# /wiki/Tandem_repeats
# /wiki/Tandem_repeats
# /wiki/Telomere
# /wiki/Trinucleotide_repeat_disorder
# /wiki/Huntington%27s_disease
# /wiki/Retrotransposon
# /wiki/RNA
# /wiki/DNA
# /wiki/Retrotransposon
# /wiki/Long_terminal_repeat
# /wiki/Long_interspersed_nuclear_element
# /wiki/Short_interspersed_nuclear_element
# /wiki/Alu_element
# /wiki/DNA_transposon
# /wiki/Caenorhabditis_elegans
# /wiki/Log%E2%80%93log_plot
# /wiki/GenBank
# /wiki/Genome_size
# /wiki/Haploid
# /wiki/Bacterial_genome_size
# /wiki/Eukaryotes
# /wiki/Developmental_biology
# /wiki/In_vivo
# /wiki/In_silico
# /wiki/Base_pair
# /wiki/Virus
# /wiki/Porcine_circovirus
# /wiki/Eukaryotic
# /wiki/Virus
# /wiki/Bacteriophage_MS2
# /wiki/Virus
# /wiki/SV40
# /wiki/Virus
# /wiki/Phi-X174_phage
# /wiki/Virus
# /wiki/HIV
# /wiki/Virus
# /wiki/Lambda_phage
# /wiki/Virus
# /wiki/Megavirus
# /wiki/Virus
# /wiki/Pandoravirus_salinus
# /wiki/Eukaryote
# /wiki/Organelle
# /wiki/Mitochondrion
# /wiki/Bacterium
# /wiki/Nasuia_deltocephalinicola
# /wiki/Leafhopper
# /wiki/Bacterium
# /wiki/Carsonella_ruddii
# /wiki/Endosymbiont
# /wiki/Psyllid
# /wiki/Bacterium
# /wiki/Buchnera_aphidicola
# /wiki/Aphid
# /wiki/Bacterium
# /wiki/Wigglesworthia_glossinidia
# /wiki/Tsetse_fly
# /wiki/Bacterium
# /wiki/Cyanobacterium
# /wiki/Prochlorococcus
# /wiki/Bacterium
# /wiki/Haemophilus_influenzae
# /wiki/Bacterium
# /wiki/Escherichia_coli
# /wiki/Bacterium
# /wiki/Nostoc_punctiforme
# /wiki/Open_reading_frame
# /wiki/Bacterium
# /wiki/Amoeboid
# /wiki/Polychaos_dubium
# /wiki/Plant
# /wiki/Genlisea_tuberosa
# /wiki/Flowering_plant
# /wiki/Plant
# /wiki/Arabidopsis_thaliana
# /wiki/Plant
# /wiki/Populus
# /wiki/Plant
# /wiki/Pinus_taeda
# /wiki/Gymnosperm
# /wiki/Angiosperm
# /wiki/Plant
# /wiki/Fritillaria_assyriaca
# /wiki/Plant
# /wiki/Paris_japonica
# /wiki/Liliales
# /wiki/Plant
# /wiki/Moss
# /wiki/Physcomitrella_patens
# /wiki/Bryophyte
# /wiki/Fungus
# /wiki/Yeast
# /wiki/Saccharomyces_cerevisiae
# /wiki/Fungus
# /wiki/Aspergillus_nidulans
# /wiki/Nematoda
# /wiki/Pratylenchus_coffeae
# /wiki/Nematoda
# /wiki/Caenorhabditis_elegans
# /wiki/Insect
# /wiki/Belgica_antarctica
# /wiki/Insect
# /wiki/Drosophila_melanogaster
# /wiki/Insect
# /wiki/Apis_mellifera
# /wiki/Insect
# /wiki/Bombyx_mori
# /wiki/Insect
# /wiki/Solenopsis_invicta
# /wiki/Crustacean
# /wiki/Antarctic_krill
# /wiki/Amphibian
# /wiki/Neuse_River_waterdog
# /wiki/Amphibian
# /wiki/Ornate_burrowing_frog
# /wiki/Mammal
# /wiki/Mus_musculus
# /wiki/Mammal
# /wiki/Pan_paniscus
# /wiki/Mammal
# /wiki/Homo_sapiens
# /wiki/Bird
# /wiki/Red_junglefowl
# /wiki/Fish
# /wiki/Tetraodon_nigroviridis
# /wiki/Fish
# /wiki/Protopterus_aethiopicus
# /wiki/V(D)J_recombination
# /wiki/Meiosis
# /wiki/Germ_cell
# /wiki/Epigenetics
# /wiki/Cell_potency
# /wiki/DNA_demethylation
# /wiki/Base_excision_repair
# /wiki/DNA_methylation
# /wiki/5-hydroxymethylcytosine
# /wiki/Tet_methylcytosine_dioxygenase_1
# /wiki/Tet_methylcytosine_dioxygenase_2
# /wiki/Gene
# /wiki/Measurement
# /wiki/Karyotype
# /wiki/Genome_size
# /wiki/Codon_usage_bias
# /wiki/GC-content
# /wiki/Gene_duplication
# /wiki/Short_tandem_repeats
# /wiki/Polyploidy
# /wiki/Horizontal_gene_transfer
# /wiki/Microbe
# /wiki/Eukaryote
# /wiki/Chloroplast
# /wiki/Mitochondria
# /wiki/Jurassic_Park_(novel)
# /wiki/Jurassic_Park_(film)
# /wiki/Gattaca
# /wiki/Bacterial_genome_size
# /wiki/Cryoconservation_of_animal_genetic_resources
# /wiki/UCSC_Genome_Browser
# /wiki/Genome_Compiler
# /wiki/Circuit_topology
# /wiki/Genome-wide_association_study
# /wiki/List_of_sequenced_animal_genomes
# /wiki/List_of_sequenced_archaeal_genomes
# /wiki/List_of_sequenced_bacterial_genomes
# /wiki/List_of_sequenced_eukaryotic_genomes
# /wiki/List_of_sequenced_fungi_genomes
# /wiki/List_of_sequenced_plant_genomes
# /wiki/List_of_sequenced_plastomes
# /wiki/List_of_sequenced_protist_genomes
# /wiki/Metagenomics
# /wiki/Microbiome
# /wiki/Molecular_epidemiology
# /wiki/Molecular_pathological_epidemiology
# /wiki/Molecular_pathology
# /wiki/Nucleic_acid_sequence
# /wiki/Pan-genome
# /wiki/Precision_medicine
# /wiki/Regulator_gene
# /wiki/Whole_genome_sequencing
# /wiki/Oxford_English_Dictionary
# /wiki/Oxford_University_Press
# /wiki/Lexico
# /wiki/Oxford_University_Press
# /wiki/Online_Etymology_Dictionary
# /wiki/Carl_Zimmer
# /wiki/The_New_York_Times
# /wiki/Wayback_Machine
# /wiki/Scientific_American
# /wiki/Craig_Venter
# /wiki/Illumina_(company)
# /wiki/454_Life_Sciences
# /wiki/Genetics
# /wiki/Introduction_to_genetics
# /wiki/Outline_of_genetics
# /wiki/History_of_genetics
# /wiki/Timeline_of_the_history_of_genetics
# /wiki/Index_of_genetics_articles
# /wiki/Glossary_of_genetics
# /wiki/Chromosome
# /wiki/DNA
# /wiki/RNA
# /wiki/Heredity
# /wiki/Nucleotide
# /wiki/Mutation
# /wiki/Genetic_variation
# /wiki/Allele
# /wiki/Amino_acid
# /wiki/Classical_genetics
# /wiki/Conservation_genetics
# /wiki/Cytogenetics
# /wiki/Ecological_genetics
# /wiki/Immunogenetics
# /wiki/Microbial_genetics
# /wiki/Molecular_genetics
# /wiki/Population_genetics
# /wiki/Quantitative_genetics
# /wiki/Archaeogenetics
# /wiki/Genetic_history_of_Africa
# /wiki/Genetic_history_of_indigenous_peoples_of_the_Americas
# /wiki/Genetic_history_of_the_British_Isles
# /wiki/Genetic_history_of_Europe
# /wiki/Genetic_history_of_Italy
# /wiki/Genetic_history_of_the_Middle_East
# /wiki/Genetics_and_archaeogenetics_of_South_Asia
# /wiki/Behavioural_genetics
# /wiki/Epigenetics
# /wiki/Geneticist
# /wiki/Genome_editing
# /wiki/Genomics
# /wiki/Genetic_code
# /wiki/Genetic_engineering
# /wiki/Genetic_diversity
# /wiki/Genetic_monitoring
# /wiki/Genetic_genealogy
# /wiki/Heredity
# /wiki/He_Jiankui_affair
# /wiki/Medical_genetics
# /wiki/Missing_heritability_problem
# /wiki/Molecular_evolution
# /wiki/Plant_genetics
# /wiki/Population_genomics
# /wiki/Reverse_genetics
# /wiki/List_of_genetic_codes
# /wiki/List_of_genetics_research_organizations
# /wiki/Omics
# /wiki/Genomics
# /wiki/Cognitive_genomics
# /wiki/Computational_genomics
# /wiki/Comparative_genomics
# /wiki/Functional_genomics
# /wiki/Genome_project
# /wiki/Human_Genome_Project
# /wiki/Metagenomics
# /wiki/Human_Microbiome_Project
# /wiki/Pangenomics
# /wiki/Personal_genomics
# /wiki/Population_genomics
# /wiki/Social_genomics
# /wiki/Structural_genomics
# /wiki/Bioinformatics
# /wiki/Biochip
# /wiki/Cheminformatics
# /wiki/Chemogenomics
# /wiki/Connectomics
# /wiki/Human_Connectome_Project
# /wiki/Epigenomics
# /wiki/Human_Epigenome_Project
# /wiki/Glycomics
# /wiki/Immunomics
# /wiki/Lipidomics
# /wiki/Metabolomics
# /wiki/Microbiome
# /wiki/Nutrigenomics
# /wiki/Paleopolyploidy
# /wiki/Pharmacogenetics
# /wiki/Pharmacogenomics
# /wiki/Systems_biology
# /wiki/Toxicogenomics
# /wiki/Transcriptomics
# /wiki/Structural_biology
# /wiki/Proteomics
# /wiki/Human_proteome_project
# /wiki/Call-map_proteomics
# /wiki/Structure-based_drug_design
# /wiki/Expression_proteomics
# /wiki/2-D_electrophoresis
# /wiki/Mass_spectrometer
# /wiki/Electrospray_ionization
# /wiki/Matrix-assisted_laser_desorption_ionization
# /wiki/Matrix-assisted_laser_desorption_ionization-time_of_flight_mass_spectrometer
# /wiki/Microfluidic-based_tools
# /wiki/Isotope_affinity_tags
# /wiki/Chromosome_conformation_capture
# /wiki/DNA_Data_Bank_of_Japan
# /wiki/European_Molecular_Biology_Laboratory
# /wiki/National_Institutes_of_Health
# /wiki/Wellcome_Sanger_Institute
# /wiki/List_of_omics_topics_in_biology
# /wiki/Self-replication
# /wiki/Life
# /wiki/Bacteria
# /wiki/Archaea
# /wiki/Eukaryote
# /wiki/Animal
# /wiki/Fungus
# /wiki/Plant
# /wiki/Protist
# /wiki/Incertae_sedis
# /wiki/Parakaryon_myojinensis
# /wiki/Biological_dark_matter
# /wiki/Virus
# /wiki/DNA_virus#Group_I:_dsDNA_viruses
# /wiki/Giant_virus
# /wiki/DNA_virus#Group_II:_ssDNA_viruses
# /wiki/Double-stranded_RNA_viruses
# /wiki/RNA_virus#Group_IV—positive-sense_ssRNA_viruses
# /wiki/RNA_virus#Group_V—negative-sense_ssRNA_viruses
# /wiki/Retrovirus
# /wiki/DsDNA-RT_virus
# /wiki/Subviral_agents
# /wiki/Viroid
# /wiki/Pospiviroidae
# /wiki/Avsunviroidae
# /wiki/Satellite_(biology)
# /wiki/Virophage
# /wiki/Virusoid
# /wiki/Defective_interfering_particle
# /wiki/Prion
# /wiki/Prion
# /wiki/Fungal_prion
# /wiki/Nucleic_acid
# /wiki/Mobile_genetic_elements
# /wiki/Mobilome
# /wiki/Horizontal_gene_transfer
# /wiki/Genomic_island
# /wiki/Transposable_element
# /wiki/Retrotransposon
# /wiki/DNA_transposon
# /wiki/Plasmid
# /wiki/Fertility_factor_(bacteria)
# /wiki/R-factor
# /wiki/Colicin
# /wiki/Virulence_factor
# /wiki/Ti_plasmid
# /wiki/Cosmid
# /wiki/Fosmid
# /wiki/Phagemid
# /wiki/Group_I_catalytic_intron
# /wiki/Group_II_intron
# /wiki/Retrozyme
# /wiki/DNA_replication
# /wiki/RNA-dependent_RNA_polymerase
# /wiki/Chromosome
# /wiki/Linear_chromosome
# /wiki/Circular_chromosome
# /wiki/Extrachromosomal_DNA
# /wiki/Secondary_chromosome
# /wiki/Gene
# /wiki/Gene_duplication
# /wiki/Non-coding_DNA
# /wiki/Origin_of_replication
# /wiki/Replicon_(genetics)
# /wiki/Endogenous_viral_element
# /wiki/Provirus
# /wiki/Prophage
# /wiki/Endogenous_retrovirus
# /wiki/Transpoviron
# /wiki/Repeated_sequence_(DNA)
# /wiki/Tandem_repeat
# /wiki/Interspersed_repeat
# /wiki/Endosymbiont
# /wiki/Mitochondrion
# /wiki/Mitosome
# /wiki/Hydrogenosome
# /wiki/Plastid
# /wiki/Chloroplast
# /wiki/Chromoplast
# /wiki/Gerontoplast
# /wiki/Leucoplast
# /wiki/Apicoplast
# /wiki/Kappa_organism
# /wiki/Bacteriome
# /wiki/Trophosome
# /wiki/Abiogenesis
# /wiki/Last_universal_common_ancestor
# /wiki/Earliest_known_life_forms
# /wiki/RNA_world
# /wiki/Ribozyme
# /wiki/Protocell
# /wiki/Coacervate
# /wiki/Proteinoid
# /wiki/Sulphobes
# /wiki/Model_lipid_bilayer
# /wiki/Jeewanu
# /wiki/Organism
# /wiki/Cell_(biology)
# /wiki/Cell_division
# /wiki/Artificial_cell
# /wiki/Non-cellular_life
# /wiki/Synthetic_virology
# /wiki/Viral_vector
# /wiki/Nanobacterium
# /wiki/Nanobe
# /wiki/Cancer_cell
# /wiki/HeLa
# /wiki/Clonally_transmissible_cancer
# /wiki/Virome

# %% [markdown]
# And finally we can automate the process. This is pretty simple really, we just do it a bunch of times!

# %%
def crawl(seed):
    links_visited = []
    suffix = '/wiki/' + seed
    # we don't want this to run forever so we only navigate 10 down
    for i in range(10):
        soup = get_soup(suffix)
        links = get_links(soup)
        suffix = random.choice(links)
        links_visited.append(suffix)
    return links_visited

# %%
links_visited = crawl('soup')

for lv in links_visited:
    print(f"Visited: {lv}")
# Out:
# Visited: /wiki/Mirepoix_(cuisine)
# Visited: /wiki/Parsnip
# Visited: /wiki/Falcarindiol
# Visited: /wiki/Nutraceutical
# Visited: /wiki/Vitamins
# Visited: /wiki/Energy_drink
# Visited: /wiki/Calcium_supplement
# Visited: /wiki/Dietary_supplement
# Visited: /wiki/Low-carbohydrate_diet
# Visited: /wiki/Pollotarianism

# %% [markdown]
# #### <span style="color:red"> Exercise 4 </span>
#
# Try the above with a new seed

# %%
links_visited = crawl('Cherry_blossom')

for lv in links_visited:
    print(f"Visited: {lv}")
# Out:
# Visited: /wiki/Prunus_padus
# Visited: /wiki/Rosaceae
# Visited: /wiki/Velloziaceae
# Visited: /wiki/Boraginaceae
# Visited: /wiki/Vitaceae
# Visited: /wiki/Sarraceniaceae
# Visited: /wiki/Himantandraceae
# Visited: /wiki/Plocospermataceae
# Visited: /wiki/Achariaceae
# Visited: /wiki/Fabaceae

# %% [markdown]
# ## Homework
#
# Your task now is to do _pretty much_ what I have done in this notebook, but with another source as your starting point.
#
# To take it futher try and find a more meaningful direction in your crawling.  Perhaps you could actually read what words are in the link, or in the page or find something which would allow your web-crawler to make a decision about _where_ it would like to go to next.
#
# It would also be great to _store this journey. [Perhaps some more metadata into a text file](https://www.w3schools.com/python/python_file_write.asp).
#
# Perhaps the web-crawler doesn't only move forward but can turn back (return to an older link) and start a new path. How would you record this journey?

# %%
#web scraper homework

import nltk

url = "https://www.thesun.co.uk/"

def soupify(url): # creates soup object out of url
    page_content = requests.get(url).content
    soup = BeautifulSoup(page_content, "html.parser")
    return soup


def find_links(soup): # finds all links connected with url on page
    page_links = soup.find_all("a")
    href_links = []
    for i in page_links:
        try:
            if i["href"] in href_links:
                pass
            else:
                href_links.append(i["href"])
        except:
            pass
    href_links = [link for link in href_links if link.startswith(url)]
    return href_links


def find_titles(soup): # looks through links for titles
    words = nltk.tokenize.word_tokenize(soup.text)
    titles = [word for word in words if word.istitle()]
    return titles

def get_words(soup):
    words = word_tokenize(soup.text)
    words_filtered =  [word.lower() for word in words if word.isalpha()]
    pos_tagged = nltk.pos_tag(words_filtered)
    nouns = filter(lambda x:x[1]=='NN',pos_tagged)
    return nouns

soup = soupify(url)
main_links = find_links(soup)

all_titles = []
all_words = []
freq_file = open("sun_freq_dist.txt", "w")

print(len(main_links))

for i in range(len((main_links))):
    current_url = random.choice(main_links)
    soup = soupify(current_url)
    main_links.remove(current_url)
    words = get_words(soup)
    #all_titles += (find_titles(soup))
    all_words += words
    print(f"Visited: {current_url}")
    freq_file.write(current_url + "\n")

fdist = FreqDist()

for word in all_words:
    fdist[word] += 1

for i in fdist.most_common():
    freq_file.write(str(i) + "\n")
freq_file.close()
# Out:
# 170
# Visited: https://www.thesun.co.uk/shopping/26229461/save-15-off-hotel-chocolat-gift-mothers-day/
# Visited: https://www.thesun.co.uk/tv/tv-news/
# Visited: https://www.thesun.co.uk/fabulous/real-life/
# Visited: https://www.thesun.co.uk/news/26431412/search-operation-ufo-norway-lake-roros/
# Visited: https://www.thesun.co.uk/motors/26424928/jaguar-ispace-m62-lost-control-crash/
# Visited: https://www.thesun.co.uk/travel/26438314/butlins-all-inclusive-breaks-seaside-holiday-parks/
# Visited: https://www.thesun.co.uk/sport/26439912/arsenal-sweden-kristoffer-olsson-brain-clots-update/
# Visited: https://www.thesun.co.uk/tvandshowbiz/26431774/katie-price-hits-back-boyfriend-jj-slater/
# Visited: https://www.thesun.co.uk/news/26440578/rookie-cop-court-affair-claims-criminal/
# Visited: https://www.thesun.co.uk/news/politics/
# Visited: https://www.thesun.co.uk/money/26401486/natwest-buy-now-pay-later-amex-credit-card-closing/
# Visited: https://www.thesun.co.uk/tv/reality/
# Visited: https://www.thesun.co.uk/sport/football/
# Visited: https://www.thesun.co.uk/syndication/
# Visited: https://www.thesun.co.uk/health/
# Visited: https://www.thesun.co.uk/editorial-complaints/
# Visited: https://www.thesun.co.uk/tv/26453238/dave-myers-wife-breaks-her-silence-hairy-bikers-death/
# Visited: https://www.thesun.co.uk/motors/26414991/parking-fine-app-payment-ticket-court-win/
# Visited: https://www.thesun.co.uk/health/wellbeing/
# Visited: https://www.thesun.co.uk/health/26413215/mum-ignored-midwives-birth-baby-death-worthing/
